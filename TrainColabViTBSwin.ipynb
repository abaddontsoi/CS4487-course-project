# %% [markdown]
# Group:
#
# Members:

# %%
# Mount google drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -r data/
# !rm -r __MACOSX/
# !rm -r test/
# !rm -r train/
# !rm -r valid/
# !rm -r 0_real/
# !rm -r 1_fake/
# !rm data.*
# !rm README.*
# Out:
# rm: cannot remove 'data/': No such file or directory
# rm: cannot remove '__MACOSX/': No such file or directory
# rm: cannot remove 'test/': No such file or directory
# rm: cannot remove 'train/': No such file or directory
# rm: cannot remove 'valid/': No such file or directory
# rm: cannot remove '0_real/': No such file or directory
# rm: cannot remove '1_fake/': No such file or directory
# rm: cannot remove 'data.*': No such file or directory
# rm: cannot remove 'README.*': No such file or directory

# %%
# !mkdir data
# !cp drive/MyDrive/CS4487/data.zip ./data.zip

# %%
# !rm -r __MACOSX/
# !rm -r AIGC-Detection-Dataset-2025
# Out:
# rm: cannot remove '__MACOSX/': No such file or directory
# rm: cannot remove 'AIGC-Detection-Dataset-2025': No such file or directory

# %%
# !unzip ./data.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: data/train/0_real/000000269997.jpg
#   inflating: __MACOSX/data/train/0_real/._000000269997.jpg
#   inflating: data/train/0_real/000000010546.jpg
#   inflating: __MACOSX/data/train/0_real/._000000010546.jpg
#   inflating: data/train/0_real/000000231524.jpg
#   inflating: __MACOSX/data/train/0_real/._000000231524.jpg
#   inflating: data/train/0_real/000000114052.jpg
#   inflating: __MACOSX/data/train/0_real/._000000114052.jpg
#   inflating: data/train/0_real/000000000999.jpg
#   inflating: __MACOSX/data/train/0_real/._000000000999.jpg
#   inflating: data/train/0_real/000000115358.jpg
#   inflating: __MACOSX/data/train/0_real/._000000115358.jpg
#   inflating: data/train/0_real/000000112437.jpg
#   inflating: __MACOSX/data/train/0_real/._000000112437.jpg
#   inflating: data/train/0_real/000000124185.jpg
#   inflating: __MACOSX/data/train/0_real/._000000124185.jpg
#   inflating: data/train/0_real/000000475129.jpg
#   inflating: __MACOSX/data/train/0_real/._000000475129.jpg
#   inflating: data/train/0_real/000000104255.jpg
#   inflating: __MACOSX/data/train/0_real/._000000104255.jpg
#   inflating: data/train/0_real/000000278656.jpg
#   inflating: __MACOSX/data/train/0_real/._000000278656.jpg
#   inflating: data/train/0_real/000000355908.jpg
#   inflating: __MACOSX/data/train/0_real/._000000355908.jpg
#   inflating: data/train/0_real/000000438029.jpg
#   inflating: __MACOSX/data/train/0_real/._000000438029.jpg
#   inflating: data/train/0_real/000000311192.jpg
#   inflating: __MACOSX/data/train/0_real/._000000311192.jpg
#   inflating: data/train/0_real/000000052761.jpg
#   inflating: __MACOSX/data/train/0_real/._000000052761.jpg
#   inflating: data/train/0_real/000000564756.jpg
#   inflating: __MACOSX/data/train/0_real/._000000564756.jpg
#   inflating: data/train/0_real/000000361475.jpg
#   inflating: __MACOSX/data/train/0_real/._000000361475.jpg
#   inflating: data/train/0_real/000000291786.jpg
#   inflating: __MACOSX/data/train/0_real/._000000291786.jpg
#   inflating: data/train/0_real/000000119562.jpg
#   inflating: __MACOSX/data/train/0_real/._000000119562.jpg
#   inflating: data/train/0_real/000000408854.jpg
#   inflating: __MACOSX/data/train/0_real/._000000408854.jpg
#   inflating: data/train/0_real/000000468178.jpg
#   inflating: __MACOSX/data/train/0_real/._000000468178.jpg
#   inflating: data/train/0_real/000000193129.jpg
#   inflating: __MACOSX/data/train/0_real/._000000193129.jpg
#   inflating: data/train/0_real/000000232987.jpg
#   inflating: __MACOSX/data/train/0_real/._000000232987.jpg
#   inflating: data/train/0_real/000000369997.jpg
#   inflating: __MACOSX/data/train/0_real/._000000369997.jpg
#   inflating: data/train/0_real/000000479075.jpg
#   inflating: __MACOSX/data/train/0_real/._000000479075.jpg
#   inflating: data/train/0_real/000000483867.jpg
#   inflating: __MACOSX/data/train/0_real/._000000483867.jpg
#   inflating: data/train/0_real/000000055768.jpg
#   inflating: __MACOSX/data/train/0_real/._000000055768.jpg
#   inflating: data/train/0_real/000000263276.jpg
#   inflating: __MACOSX/data/train/0_real/._000000263276.jpg
#   inflating: data/train/0_real/000000096723.jpg
#   inflating: __MACOSX/data/train/0_real/._000000096723.jpg
#   inflating: data/train/0_real/000000530461.jpg
#   inflating: __MACOSX/data/train/0_real/._000000530461.jpg
#   inflating: data/train/0_real/000000093883.jpg
#   inflating: __MACOSX/data/train/0_real/._000000093883.jpg
#   inflating: data/train/0_real/000000454681.jpg
#   inflating: __MACOSX/data/train/0_real/._000000454681.jpg
#   inflating: data/train/0_real/000000132081.jpg
#   inflating: __MACOSX/data/train/0_real/._000000132081.jpg
#   inflating: data/train/0_real/000000261461.jpg
#   inflating: __MACOSX/data/train/0_real/._000000261461.jpg
#   inflating: data/train/0_real/000000152946.jpg
#   inflating: __MACOSX/data/train/0_real/._000000152946.jpg
#   inflating: data/train/0_real/000000491250.jpg
#   inflating: __MACOSX/data/train/0_real/._000000491250.jpg
#   inflating: data/train/0_real/000000237814.jpg
#   inflating: __MACOSX/data/train/0_real/._000000237814.jpg
#   inflating: data/train/0_real/000000442008.jpg
#   inflating: __MACOSX/data/train/0_real/._000000442008.jpg
#   inflating: data/train/0_real/000000552569.jpg
#   inflating: __MACOSX/data/train/0_real/._000000552569.jpg
#   inflating: data/train/0_real/000000581731.jpg
#   inflating: __MACOSX/data/train/0_real/._000000581731.jpg
#   inflating: data/train/0_real/000000316170.jpg
#   inflating: __MACOSX/data/train/0_real/._000000316170.jpg
#   inflating: data/train/0_real/000000065898.jpg
#   inflating: __MACOSX/data/train/0_real/._000000065898.jpg
#   inflating: data/train/0_real/000000168416.jpg
#   inflating: __MACOSX/data/train/0_real/._000000168416.jpg
#   inflating: data/train/0_real/000000447170.jpg
#   inflating: __MACOSX/data/train/0_real/._000000447170.jpg
#   inflating: data/train/0_real/000000289644.jpg
#   inflating: __MACOSX/data/train/0_real/._000000289644.jpg
#   inflating: data/train/0_real/000000073022.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073022.jpg
#   inflating: data/train/0_real/000000515622.jpg
#   inflating: __MACOSX/data/train/0_real/._000000515622.jpg
#   inflating: data/train/0_real/000000035711.jpg
#   inflating: __MACOSX/data/train/0_real/._000000035711.jpg
#   inflating: data/train/0_real/000000525087.jpg
#   inflating: __MACOSX/data/train/0_real/._000000525087.jpg
#   inflating: data/train/0_real/000000137674.jpg
#   inflating: __MACOSX/data/train/0_real/._000000137674.jpg
#   inflating: data/train/0_real/000000451074.jpg
#   inflating: __MACOSX/data/train/0_real/._000000451074.jpg
#   inflating: data/train/0_real/000000212302.jpg
#   inflating: __MACOSX/data/train/0_real/._000000212302.jpg
#   inflating: data/train/0_real/000000384374.jpg
#   inflating: __MACOSX/data/train/0_real/._000000384374.jpg
#   inflating: data/train/0_real/000000485543.jpg
#   inflating: __MACOSX/data/train/0_real/._000000485543.jpg
#   inflating: data/train/0_real/000000495750.jpg
#   inflating: __MACOSX/data/train/0_real/._000000495750.jpg
#   inflating: data/train/0_real/000000354425.jpg
#   inflating: __MACOSX/data/train/0_real/._000000354425.jpg
#   inflating: data/train/0_real/000000276848.jpg
#   inflating: __MACOSX/data/train/0_real/._000000276848.jpg
#   inflating: data/train/0_real/000000343159.jpg
#   inflating: __MACOSX/data/train/0_real/._000000343159.jpg
#   inflating: data/train/0_real/000000294615.jpg
#   inflating: __MACOSX/data/train/0_real/._000000294615.jpg
#   inflating: data/train/0_real/000000021764.jpg
#   inflating: __MACOSX/data/train/0_real/._000000021764.jpg
#   inflating: data/train/0_real/000000403040.jpg
#   inflating: __MACOSX/data/train/0_real/._000000403040.jpg
#   inflating: data/train/0_real/000000510028.jpg
#   inflating: __MACOSX/data/train/0_real/._000000510028.jpg
#   inflating: data/train/0_real/000000509579.jpg
#   inflating: __MACOSX/data/train/0_real/._000000509579.jpg
#   inflating: data/train/0_real/000000487340.jpg
#   inflating: __MACOSX/data/train/0_real/._000000487340.jpg
#   inflating: data/train/0_real/000000178177.jpg
#   inflating: __MACOSX/data/train/0_real/._000000178177.jpg
#   inflating: data/train/0_real/000000157194.jpg
#   inflating: __MACOSX/data/train/0_real/._000000157194.jpg
#   inflating: data/train/0_real/000000299325.jpg
#   inflating: __MACOSX/data/train/0_real/._000000299325.jpg
#   inflating: data/train/0_real/000000477919.jpg
#   inflating: __MACOSX/data/train/0_real/._000000477919.jpg
#   inflating: data/train/0_real/000000555574.jpg
#   inflating: __MACOSX/data/train/0_real/._000000555574.jpg
#   inflating: data/train/0_real/000000146099.jpg
#   inflating: __MACOSX/data/train/0_real/._000000146099.jpg
#   inflating: data/train/0_real/000000138553.jpg
#   inflating: __MACOSX/data/train/0_real/._000000138553.jpg
#   inflating: data/train/0_real/000000244636.jpg
#   inflating: __MACOSX/data/train/0_real/._000000244636.jpg
#   inflating: data/train/0_real/000000417753.jpg
#   inflating: __MACOSX/data/train/0_real/._000000417753.jpg
#   inflating: data/train/0_real/000000533197.jpg
#   inflating: __MACOSX/data/train/0_real/._000000533197.jpg
#   inflating: data/train/0_real/000000296770.jpg
#   inflating: __MACOSX/data/train/0_real/._000000296770.jpg
#   inflating: data/train/0_real/000000214001.jpg
#   inflating: __MACOSX/data/train/0_real/._000000214001.jpg
#   inflating: data/train/0_real/000000188290.jpg
#   inflating: __MACOSX/data/train/0_real/._000000188290.jpg
#   inflating: data/train/0_real/000000557405.jpg
#   inflating: __MACOSX/data/train/0_real/._000000557405.jpg
#   inflating: data/train/0_real/000000142599.jpg
#   inflating: __MACOSX/data/train/0_real/._000000142599.jpg
#   inflating: data/train/0_real/000000020308.jpg
#   inflating: __MACOSX/data/train/0_real/._000000020308.jpg
#   inflating: data/train/0_real/000000459372.jpg
#   inflating: __MACOSX/data/train/0_real/._000000459372.jpg
#   inflating: data/train/0_real/000000562496.jpg
#   inflating: __MACOSX/data/train/0_real/._000000562496.jpg
#   inflating: data/train/0_real/000000296758.jpg
#   inflating: __MACOSX/data/train/0_real/._000000296758.jpg
#   inflating: data/train/0_real/000000318161.jpg
#   inflating: __MACOSX/data/train/0_real/._000000318161.jpg
#   inflating: data/train/0_real/000000281224.jpg
#   inflating: __MACOSX/data/train/0_real/._000000281224.jpg
#   inflating: data/train/0_real/000000534808.jpg
#   inflating: __MACOSX/data/train/0_real/._000000534808.jpg
#   inflating: data/train/0_real/000000129310.jpg
#   inflating: __MACOSX/data/train/0_real/._000000129310.jpg
#   inflating: data/train/0_real/000000064562.jpg
#   inflating: __MACOSX/data/train/0_real/._000000064562.jpg
#   inflating: data/train/0_real/000000321938.jpg
#   inflating: __MACOSX/data/train/0_real/._000000321938.jpg
#   inflating: data/train/0_real/000000039671.jpg
#   inflating: __MACOSX/data/train/0_real/._000000039671.jpg
#   inflating: data/train/0_real/000000036542.jpg
#   inflating: __MACOSX/data/train/0_real/._000000036542.jpg
#   inflating: data/train/0_real/000000386239.jpg
#   inflating: __MACOSX/data/train/0_real/._000000386239.jpg
#   inflating: data/train/0_real/000000508129.jpg
#   inflating: __MACOSX/data/train/0_real/._000000508129.jpg
#   inflating: data/train/0_real/000000231281.jpg
#   inflating: __MACOSX/data/train/0_real/._000000231281.jpg
#   inflating: data/train/0_real/000000240478.jpg
#   inflating: __MACOSX/data/train/0_real/._000000240478.jpg
#   inflating: data/train/0_real/000000559400.jpg
#   inflating: __MACOSX/data/train/0_real/._000000559400.jpg
#   inflating: data/train/0_real/000000343603.jpg
#   inflating: __MACOSX/data/train/0_real/._000000343603.jpg
#   inflating: data/train/0_real/000000314983.jpg
#   inflating: __MACOSX/data/train/0_real/._000000314983.jpg
#   inflating: data/train/0_real/000000455548.jpg
#   inflating: __MACOSX/data/train/0_real/._000000455548.jpg
#   inflating: data/train/0_real/000000124152.jpg
#   inflating: __MACOSX/data/train/0_real/._000000124152.jpg
#   inflating: data/train/0_real/000000190391.jpg
#   inflating: __MACOSX/data/train/0_real/._000000190391.jpg
#   inflating: data/train/0_real/000000509551.jpg
#   inflating: __MACOSX/data/train/0_real/._000000509551.jpg
#   inflating: data/train/0_real/000000070271.jpg
#   inflating: __MACOSX/data/train/0_real/._000000070271.jpg
#   inflating: data/train/0_real/000000245266.jpg
#   inflating: __MACOSX/data/train/0_real/._000000245266.jpg
#   inflating: data/train/0_real/000000411478.jpg
#   inflating: __MACOSX/data/train/0_real/._000000411478.jpg
#   inflating: data/train/0_real/000000502410.jpg
#   inflating: __MACOSX/data/train/0_real/._000000502410.jpg
#   inflating: data/train/0_real/000000479908.jpg
#   inflating: __MACOSX/data/train/0_real/._000000479908.jpg
#   inflating: data/train/0_real/000000299319.jpg
#   inflating: __MACOSX/data/train/0_real/._000000299319.jpg
#   inflating: data/train/0_real/000000273918.jpg
#   inflating: __MACOSX/data/train/0_real/._000000273918.jpg
#   inflating: data/train/0_real/000000136542.jpg
#   inflating: __MACOSX/data/train/0_real/._000000136542.jpg
#   inflating: data/train/0_real/000000170517.jpg
#   inflating: __MACOSX/data/train/0_real/._000000170517.jpg
#   inflating: data/train/0_real/000000032056.jpg
#   inflating: __MACOSX/data/train/0_real/._000000032056.jpg
#   inflating: data/train/0_real/000000205656.jpg
#   inflating: __MACOSX/data/train/0_real/._000000205656.jpg
#   inflating: data/train/0_real/000000449613.jpg
#   inflating: __MACOSX/data/train/0_real/._000000449613.jpg
#   inflating: data/train/0_real/000000500207.jpg
#   inflating: __MACOSX/data/train/0_real/._000000500207.jpg
#   inflating: data/train/0_real/000000499142.jpg
#   inflating: __MACOSX/data/train/0_real/._000000499142.jpg
#   inflating: data/train/0_real/000000187821.jpg
#   inflating: __MACOSX/data/train/0_real/._000000187821.jpg
#   inflating: data/train/0_real/000000387655.jpg
#   inflating: __MACOSX/data/train/0_real/._000000387655.jpg
#   inflating: data/train/0_real/000000425905.jpg
#   inflating: __MACOSX/data/train/0_real/._000000425905.jpg
#   inflating: data/train/0_real/000000207041.jpg
#   inflating: __MACOSX/data/train/0_real/._000000207041.jpg
#   inflating: data/train/0_real/000000454642.jpg
#   inflating: __MACOSX/data/train/0_real/._000000454642.jpg
#   inflating: data/train/0_real/000000122251.jpg
#   inflating: __MACOSX/data/train/0_real/._000000122251.jpg
#   inflating: data/train/0_real/000000335781.jpg
#   inflating: __MACOSX/data/train/0_real/._000000335781.jpg
#   inflating: data/train/0_real/000000284348.jpg
#   inflating: __MACOSX/data/train/0_real/._000000284348.jpg
#   inflating: data/train/0_real/000000436979.jpg
#   inflating: __MACOSX/data/train/0_real/._000000436979.jpg
#   inflating: data/train/0_real/000000176600.jpg
#   inflating: __MACOSX/data/train/0_real/._000000176600.jpg
#   inflating: data/train/0_real/000000311637.jpg
#   inflating: __MACOSX/data/train/0_real/._000000311637.jpg
#   inflating: data/train/0_real/000000476385.jpg
#   inflating: __MACOSX/data/train/0_real/._000000476385.jpg
#   inflating: data/train/0_real/000000385724.jpg
#   inflating: __MACOSX/data/train/0_real/._000000385724.jpg
#   inflating: data/train/0_real/000000258544.jpg
#   inflating: __MACOSX/data/train/0_real/._000000258544.jpg
#   inflating: data/train/0_real/000000162112.jpg
#   inflating: __MACOSX/data/train/0_real/._000000162112.jpg
#   inflating: data/train/0_real/000000456732.jpg
#   inflating: __MACOSX/data/train/0_real/._000000456732.jpg
#   inflating: data/train/0_real/000000542035.jpg
#   inflating: __MACOSX/data/train/0_real/._000000542035.jpg
#   inflating: data/train/0_real/000000074002.jpg
#   inflating: __MACOSX/data/train/0_real/._000000074002.jpg
#   inflating: data/train/0_real/000000484674.jpg
#   inflating: __MACOSX/data/train/0_real/._000000484674.jpg
#   inflating: data/train/0_real/000000317521.jpg
#   inflating: __MACOSX/data/train/0_real/._000000317521.jpg
#   inflating: data/train/0_real/000000479909.jpg
#   inflating: __MACOSX/data/train/0_real/._000000479909.jpg
#   inflating: data/train/0_real/000000359128.jpg
#   inflating: __MACOSX/data/train/0_real/._000000359128.jpg
#   inflating: data/train/0_real/000000406105.jpg
#   inflating: __MACOSX/data/train/0_real/._000000406105.jpg
#   inflating: data/train/0_real/000000439493.jpg
#   inflating: __MACOSX/data/train/0_real/._000000439493.jpg
#   inflating: data/train/0_real/000000255706.jpg
#   inflating: __MACOSX/data/train/0_real/._000000255706.jpg
#   inflating: data/train/0_real/000000318174.jpg
#   inflating: __MACOSX/data/train/0_real/._000000318174.jpg
#   inflating: data/train/0_real/000000254418.jpg
#   inflating: __MACOSX/data/train/0_real/._000000254418.jpg
#   inflating: data/train/0_real/000000185789.jpg
#   inflating: __MACOSX/data/train/0_real/._000000185789.jpg
#   inflating: data/train/0_real/000000120447.jpg
#   inflating: __MACOSX/data/train/0_real/._000000120447.jpg
#   inflating: data/train/0_real/000000563945.jpg
#   inflating: __MACOSX/data/train/0_real/._000000563945.jpg
#   inflating: data/train/0_real/000000482563.jpg
#   inflating: __MACOSX/data/train/0_real/._000000482563.jpg
#   inflating: data/train/0_real/000000082794.jpg
#   inflating: __MACOSX/data/train/0_real/._000000082794.jpg
#   inflating: data/train/0_real/000000172467.jpg
#   inflating: __MACOSX/data/train/0_real/._000000172467.jpg
#   inflating: data/train/0_real/000000556726.jpg
#   inflating: __MACOSX/data/train/0_real/._000000556726.jpg
#   inflating: data/train/0_real/000000164205.jpg
#   inflating: __MACOSX/data/train/0_real/._000000164205.jpg
#   inflating: data/train/0_real/000000071608.jpg
#   inflating: __MACOSX/data/train/0_real/._000000071608.jpg
#   inflating: data/train/0_real/000000499631.jpg
#   inflating: __MACOSX/data/train/0_real/._000000499631.jpg
#   inflating: data/train/0_real/000000475699.jpg
#   inflating: __MACOSX/data/train/0_real/._000000475699.jpg
#   inflating: data/train/0_real/000000231280.jpg
#   inflating: __MACOSX/data/train/0_real/._000000231280.jpg
#   inflating: data/train/0_real/000000486711.jpg
#   inflating: __MACOSX/data/train/0_real/._000000486711.jpg
#   inflating: data/train/0_real/000000444444.jpg
#   inflating: __MACOSX/data/train/0_real/._000000444444.jpg
#   inflating: data/train/0_real/000000164211.jpg
#   inflating: __MACOSX/data/train/0_real/._000000164211.jpg
#   inflating: data/train/0_real/000000453138.jpg
#   inflating: __MACOSX/data/train/0_real/._000000453138.jpg
#   inflating: data/train/0_real/000000068359.jpg
#   inflating: __MACOSX/data/train/0_real/._000000068359.jpg
#   inflating: data/train/0_real/000000041913.jpg
#   inflating: __MACOSX/data/train/0_real/._000000041913.jpg
#   inflating: data/train/0_real/000000406677.jpg
#   inflating: __MACOSX/data/train/0_real/._000000406677.jpg
#   inflating: data/train/0_real/000000022536.jpg
#   inflating: __MACOSX/data/train/0_real/._000000022536.jpg
#   inflating: data/train/0_real/000000185945.jpg
#   inflating: __MACOSX/data/train/0_real/._000000185945.jpg
#   inflating: data/train/0_real/000000055966.jpg
#   inflating: __MACOSX/data/train/0_real/._000000055966.jpg
#   inflating: data/train/0_real/000000223684.jpg
#   inflating: __MACOSX/data/train/0_real/._000000223684.jpg
#   inflating: data/train/0_real/000000369799.jpg
#   inflating: __MACOSX/data/train/0_real/._000000369799.jpg
#   inflating: data/train/0_real/000000179240.jpg
#   inflating: __MACOSX/data/train/0_real/._000000179240.jpg
#   inflating: data/train/0_real/000000241001.jpg
#   inflating: __MACOSX/data/train/0_real/._000000241001.jpg
#   inflating: data/train/0_real/000000303540.jpg
#   inflating: __MACOSX/data/train/0_real/._000000303540.jpg
#   inflating: data/train/0_real/000000210528.jpg
#   inflating: __MACOSX/data/train/0_real/._000000210528.jpg
#   inflating: data/train/0_real/000000541528.jpg
#   inflating: __MACOSX/data/train/0_real/._000000541528.jpg
#   inflating: data/train/0_real/000000496264.jpg
#   inflating: __MACOSX/data/train/0_real/._000000496264.jpg
#   inflating: data/train/0_real/000000357139.jpg
#   inflating: __MACOSX/data/train/0_real/._000000357139.jpg
#   inflating: data/train/0_real/000000080801.jpg
#   inflating: __MACOSX/data/train/0_real/._000000080801.jpg
#   inflating: data/train/0_real/000000244151.jpg
#   inflating: __MACOSX/data/train/0_real/._000000244151.jpg
#   inflating: data/train/0_real/000000024609.jpg
#   inflating: __MACOSX/data/train/0_real/._000000024609.jpg
#   inflating: data/train/0_real/000000099388.jpg
#   inflating: __MACOSX/data/train/0_real/._000000099388.jpg
#   inflating: data/train/0_real/000000146098.jpg
#   inflating: __MACOSX/data/train/0_real/._000000146098.jpg
#   inflating: data/train/0_real/000000513520.jpg
#   inflating: __MACOSX/data/train/0_real/._000000513520.jpg
#   inflating: data/train/0_real/000000479935.jpg
#   inflating: __MACOSX/data/train/0_real/._000000479935.jpg
#   inflating: data/train/0_real/000000043692.jpg
#   inflating: __MACOSX/data/train/0_real/._000000043692.jpg
#   inflating: data/train/0_real/000000382710.jpg
#   inflating: __MACOSX/data/train/0_real/._000000382710.jpg
#   inflating: data/train/0_real/000000246746.jpg
#   inflating: __MACOSX/data/train/0_real/._000000246746.jpg
#   inflating: data/train/0_real/000000278870.jpg
#   inflating: __MACOSX/data/train/0_real/._000000278870.jpg
#   inflating: data/train/0_real/000000031562.jpg
#   inflating: __MACOSX/data/train/0_real/._000000031562.jpg
#   inflating: data/train/0_real/000000078604.jpg
#   inflating: __MACOSX/data/train/0_real/._000000078604.jpg
#   inflating: data/train/0_real/000000488072.jpg
#   inflating: __MACOSX/data/train/0_real/._000000488072.jpg
#   inflating: data/train/0_real/000000041085.jpg
#   inflating: __MACOSX/data/train/0_real/._000000041085.jpg
#   inflating: data/train/0_real/000000250124.jpg
#   inflating: __MACOSX/data/train/0_real/._000000250124.jpg
#   inflating: data/train/0_real/000000398748.jpg
#   inflating: __MACOSX/data/train/0_real/._000000398748.jpg
#   inflating: data/train/0_real/000000211178.jpg
#   inflating: __MACOSX/data/train/0_real/._000000211178.jpg
#   inflating: data/train/0_real/000000508100.jpg
#   inflating: __MACOSX/data/train/0_real/._000000508100.jpg
#   inflating: data/train/0_real/000000027466.jpg
#   inflating: __MACOSX/data/train/0_real/._000000027466.jpg
#   inflating: data/train/0_real/000000191918.jpg
#   inflating: __MACOSX/data/train/0_real/._000000191918.jpg
#   inflating: data/train/0_real/000000510997.jpg
#   inflating: __MACOSX/data/train/0_real/._000000510997.jpg
#   inflating: data/train/0_real/000000125503.jpg
#   inflating: __MACOSX/data/train/0_real/._000000125503.jpg
#   inflating: data/train/0_real/000000100973.jpg
#   inflating: __MACOSX/data/train/0_real/._000000100973.jpg
#   inflating: data/train/0_real/000000346752.jpg
#   inflating: __MACOSX/data/train/0_real/._000000346752.jpg
#   inflating: data/train/0_real/000000378864.jpg
#   inflating: __MACOSX/data/train/0_real/._000000378864.jpg
#   inflating: data/train/0_real/000000033413.jpg
#   inflating: __MACOSX/data/train/0_real/._000000033413.jpg
#   inflating: data/train/0_real/000000128027.jpg
#   inflating: __MACOSX/data/train/0_real/._000000128027.jpg
#   inflating: data/train/0_real/000000065655.jpg
#   inflating: __MACOSX/data/train/0_real/._000000065655.jpg
#   inflating: data/train/0_real/000000306376.jpg
#   inflating: __MACOSX/data/train/0_real/._000000306376.jpg
#   inflating: data/train/0_real/000000401124.jpg
#   inflating: __MACOSX/data/train/0_real/._000000401124.jpg
#   inflating: data/train/0_real/000000063230.jpg
#   inflating: __MACOSX/data/train/0_real/._000000063230.jpg
#   inflating: data/train/0_real/000000349475.jpg
#   inflating: __MACOSX/data/train/0_real/._000000349475.jpg
#   inflating: data/train/0_real/000000138220.jpg
#   inflating: __MACOSX/data/train/0_real/._000000138220.jpg
#   inflating: data/train/0_real/000000280107.jpg
#   inflating: __MACOSX/data/train/0_real/._000000280107.jpg
#   inflating: data/train/0_real/000000367788.jpg
#   inflating: __MACOSX/data/train/0_real/._000000367788.jpg
#   inflating: data/train/0_real/000000176629.jpg
#   inflating: __MACOSX/data/train/0_real/._000000176629.jpg
#   inflating: data/train/0_real/000000206410.jpg
#   inflating: __MACOSX/data/train/0_real/._000000206410.jpg
#   inflating: data/train/0_real/000000445766.jpg
#   inflating: __MACOSX/data/train/0_real/._000000445766.jpg
#   inflating: data/train/0_real/000000453104.jpg
#   inflating: __MACOSX/data/train/0_real/._000000453104.jpg
#   inflating: data/train/0_real/000000415151.jpg
#   inflating: __MACOSX/data/train/0_real/._000000415151.jpg
#   inflating: data/train/0_real/000000389137.jpg
#   inflating: __MACOSX/data/train/0_real/._000000389137.jpg
#   inflating: data/train/0_real/000000342520.jpg
#   inflating: __MACOSX/data/train/0_real/._000000342520.jpg
#   inflating: data/train/0_real/000000257887.jpg
#   inflating: __MACOSX/data/train/0_real/._000000257887.jpg
#   inflating: data/train/0_real/000000282076.jpg
#   inflating: __MACOSX/data/train/0_real/._000000282076.jpg
#   inflating: data/train/0_real/000000541514.jpg
#   inflating: __MACOSX/data/train/0_real/._000000541514.jpg
#   inflating: data/train/0_real/000000344637.jpg
#   inflating: __MACOSX/data/train/0_real/._000000344637.jpg
#   inflating: data/train/0_real/000000569298.jpg
#   inflating: __MACOSX/data/train/0_real/._000000569298.jpg
#   inflating: data/train/0_real/000000075334.jpg
#   inflating: __MACOSX/data/train/0_real/._000000075334.jpg
#   inflating: data/train/0_real/000000384375.jpg
#   inflating: __MACOSX/data/train/0_real/._000000384375.jpg
#   inflating: data/train/0_real/000000033361.jpg
#   inflating: __MACOSX/data/train/0_real/._000000033361.jpg
#   inflating: data/train/0_real/000000063556.jpg
#   inflating: __MACOSX/data/train/0_real/._000000063556.jpg
#   inflating: data/train/0_real/000000317509.jpg
#   inflating: __MACOSX/data/train/0_real/._000000317509.jpg
#   inflating: data/train/0_real/000000147392.jpg
#   inflating: __MACOSX/data/train/0_real/._000000147392.jpg
#   inflating: data/train/0_real/000000411451.jpg
#   inflating: __MACOSX/data/train/0_real/._000000411451.jpg
#   inflating: data/train/0_real/000000338501.jpg
#   inflating: __MACOSX/data/train/0_real/._000000338501.jpg
#   inflating: data/train/0_real/000000178189.jpg
#   inflating: __MACOSX/data/train/0_real/._000000178189.jpg
#   inflating: data/train/0_real/000000395293.jpg
#   inflating: __MACOSX/data/train/0_real/._000000395293.jpg
#   inflating: data/train/0_real/000000327421.jpg
#   inflating: __MACOSX/data/train/0_real/._000000327421.jpg
#   inflating: data/train/0_real/000000023199.jpg
#   inflating: __MACOSX/data/train/0_real/._000000023199.jpg
#   inflating: data/train/0_real/000000052760.jpg
#   inflating: __MACOSX/data/train/0_real/._000000052760.jpg
#   inflating: data/train/0_real/000000367005.jpg
#   inflating: __MACOSX/data/train/0_real/._000000367005.jpg
#   inflating: data/train/0_real/000000073976.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073976.jpg
#   inflating: data/train/0_real/000000186525.jpg
#   inflating: __MACOSX/data/train/0_real/._000000186525.jpg
#   inflating: data/train/0_real/000000396942.jpg
#   inflating: __MACOSX/data/train/0_real/._000000396942.jpg
#   inflating: data/train/0_real/000000325236.jpg
#   inflating: __MACOSX/data/train/0_real/._000000325236.jpg
#   inflating: data/train/0_real/000000267777.jpg
#   inflating: __MACOSX/data/train/0_real/._000000267777.jpg
#   inflating: data/train/0_real/000000462454.jpg
#   inflating: __MACOSX/data/train/0_real/._000000462454.jpg
#   inflating: data/train/0_real/000000020490.jpg
#   inflating: __MACOSX/data/train/0_real/._000000020490.jpg
#   inflating: data/train/0_real/000000266469.jpg
#   inflating: __MACOSX/data/train/0_real/._000000266469.jpg
#   inflating: data/train/0_real/000000050177.jpg
#   inflating: __MACOSX/data/train/0_real/._000000050177.jpg
#   inflating: data/train/0_real/000000180154.jpg
#   inflating: __MACOSX/data/train/0_real/._000000180154.jpg
#   inflating: data/train/0_real/000000115359.jpg
#   inflating: __MACOSX/data/train/0_real/._000000115359.jpg
#   inflating: data/train/0_real/000000453689.jpg
#   inflating: __MACOSX/data/train/0_real/._000000453689.jpg
#   inflating: data/train/0_real/000000071807.jpg
#   inflating: __MACOSX/data/train/0_real/._000000071807.jpg
#   inflating: data/train/0_real/000000540187.jpg
#   inflating: __MACOSX/data/train/0_real/._000000540187.jpg
#   inflating: data/train/0_real/000000237626.jpg
#   inflating: __MACOSX/data/train/0_real/._000000237626.jpg
#   inflating: data/train/0_real/000000424367.jpg
#   inflating: __MACOSX/data/train/0_real/._000000424367.jpg
#   inflating: data/train/0_real/000000454858.jpg
#   inflating: __MACOSX/data/train/0_real/._000000454858.jpg
#   inflating: data/train/0_real/000000547830.jpg
#   inflating: __MACOSX/data/train/0_real/._000000547830.jpg
#   inflating: data/train/0_real/000000377570.jpg
#   inflating: __MACOSX/data/train/0_real/._000000377570.jpg
#   inflating: data/train/0_real/000000182025.jpg
#   inflating: __MACOSX/data/train/0_real/._000000182025.jpg
#   inflating: data/train/0_real/000000564031.jpg
#   inflating: __MACOSX/data/train/0_real/._000000564031.jpg
#   inflating: data/train/0_real/000000131589.jpg
#   inflating: __MACOSX/data/train/0_real/._000000131589.jpg
#   inflating: data/train/0_real/000000213790.jpg
#   inflating: __MACOSX/data/train/0_real/._000000213790.jpg
#   inflating: data/train/0_real/000000080140.jpg
#   inflating: __MACOSX/data/train/0_real/._000000080140.jpg
#   inflating: data/train/0_real/000000013728.jpg
#   inflating: __MACOSX/data/train/0_real/._000000013728.jpg
#   inflating: data/train/0_real/000000156506.jpg
#   inflating: __MACOSX/data/train/0_real/._000000156506.jpg
#   inflating: data/train/0_real/000000378657.jpg
#   inflating: __MACOSX/data/train/0_real/._000000378657.jpg
#   inflating: data/train/0_real/000000044670.jpg
#   inflating: __MACOSX/data/train/0_real/._000000044670.jpg
#   inflating: data/train/0_real/000000265612.jpg
#   inflating: __MACOSX/data/train/0_real/._000000265612.jpg
#   inflating: data/train/0_real/000000540193.jpg
#   inflating: __MACOSX/data/train/0_real/._000000540193.jpg
#   inflating: data/train/0_real/000000497807.jpg
#   inflating: __MACOSX/data/train/0_real/._000000497807.jpg
#   inflating: data/train/0_real/000000218809.jpg
#   inflating: __MACOSX/data/train/0_real/._000000218809.jpg
#   inflating: data/train/0_real/000000067917.jpg
#   inflating: __MACOSX/data/train/0_real/._000000067917.jpg
#   inflating: data/train/0_real/000000508855.jpg
#   inflating: __MACOSX/data/train/0_real/._000000508855.jpg
#   inflating: data/train/0_real/000000422064.jpg
#   inflating: __MACOSX/data/train/0_real/._000000422064.jpg
#   inflating: data/train/0_real/000000128972.jpg
#   inflating: __MACOSX/data/train/0_real/._000000128972.jpg
#   inflating: data/train/0_real/000000361460.jpg
#   inflating: __MACOSX/data/train/0_real/._000000361460.jpg
#   inflating: data/train/0_real/000000273716.jpg
#   inflating: __MACOSX/data/train/0_real/._000000273716.jpg
#   inflating: data/train/0_real/000000215493.jpg
#   inflating: __MACOSX/data/train/0_real/._000000215493.jpg
#   inflating: data/train/0_real/000000214955.jpg
#   inflating: __MACOSX/data/train/0_real/._000000214955.jpg
#   inflating: data/train/0_real/000000099363.jpg
#   inflating: __MACOSX/data/train/0_real/._000000099363.jpg
#   inflating: data/train/0_real/000000226071.jpg
#   inflating: __MACOSX/data/train/0_real/._000000226071.jpg
#   inflating: data/train/0_real/000000209092.jpg
#   inflating: __MACOSX/data/train/0_real/._000000209092.jpg
#   inflating: data/train/0_real/000000528575.jpg
#   inflating: __MACOSX/data/train/0_real/._000000528575.jpg
#   inflating: data/train/0_real/000000268478.jpg
#   inflating: __MACOSX/data/train/0_real/._000000268478.jpg
#   inflating: data/train/0_real/000000175491.jpg
#   inflating: __MACOSX/data/train/0_real/._000000175491.jpg
#   inflating: data/train/0_real/000000551908.jpg
#   inflating: __MACOSX/data/train/0_real/._000000551908.jpg
#   inflating: data/train/0_real/000000478430.jpg
#   inflating: __MACOSX/data/train/0_real/._000000478430.jpg
#   inflating: data/train/0_real/000000243825.jpg
#   inflating: __MACOSX/data/train/0_real/._000000243825.jpg
#   inflating: data/train/0_real/000000535242.jpg
#   inflating: __MACOSX/data/train/0_real/._000000535242.jpg
#   inflating: data/train/0_real/000000495786.jpg
#   inflating: __MACOSX/data/train/0_real/._000000495786.jpg
#   inflating: data/train/0_real/000000575666.jpg
#   inflating: __MACOSX/data/train/0_real/._000000575666.jpg
#   inflating: data/train/0_real/000000309086.jpg
#   inflating: __MACOSX/data/train/0_real/._000000309086.jpg
#   inflating: data/train/0_real/000000379561.jpg
#   inflating: __MACOSX/data/train/0_real/._000000379561.jpg
#   inflating: data/train/0_real/000000176826.jpg
#   inflating: __MACOSX/data/train/0_real/._000000176826.jpg
#   inflating: data/train/0_real/000000275429.jpg
#   inflating: __MACOSX/data/train/0_real/._000000275429.jpg
#   inflating: data/train/0_real/000000188252.jpg
#   inflating: __MACOSX/data/train/0_real/._000000188252.jpg
#   inflating: data/train/0_real/000000577717.jpg
#   inflating: __MACOSX/data/train/0_real/._000000577717.jpg
#   inflating: data/train/0_real/000000556901.jpg
#   inflating: __MACOSX/data/train/0_real/._000000556901.jpg
#   inflating: data/train/0_real/000000172498.jpg
#   inflating: __MACOSX/data/train/0_real/._000000172498.jpg
#   inflating: data/train/0_real/000000364256.jpg
#   inflating: __MACOSX/data/train/0_real/._000000364256.jpg
#   inflating: data/train/0_real/000000322203.jpg
#   inflating: __MACOSX/data/train/0_real/._000000322203.jpg
#   inflating: data/train/0_real/000000323109.jpg
#   inflating: __MACOSX/data/train/0_real/._000000323109.jpg
#   inflating: data/train/0_real/000000171185.jpg
#   inflating: __MACOSX/data/train/0_real/._000000171185.jpg
#   inflating: data/train/0_real/000000300908.jpg
#   inflating: __MACOSX/data/train/0_real/._000000300908.jpg
#   inflating: data/train/0_real/000000407596.jpg
#   inflating: __MACOSX/data/train/0_real/._000000407596.jpg
#   inflating: data/train/0_real/000000379575.jpg
#   inflating: __MACOSX/data/train/0_real/._000000379575.jpg
#   inflating: data/train/0_real/000000492943.jpg
#   inflating: __MACOSX/data/train/0_real/._000000492943.jpg
#   inflating: data/train/0_real/000000431024.jpg
#   inflating: __MACOSX/data/train/0_real/._000000431024.jpg
#   inflating: data/train/0_real/000000299495.jpg
#   inflating: __MACOSX/data/train/0_real/._000000299495.jpg
#   inflating: data/train/0_real/000000366455.jpg
#   inflating: __MACOSX/data/train/0_real/._000000366455.jpg
#   inflating: data/train/0_real/000000116678.jpg
#   inflating: __MACOSX/data/train/0_real/._000000116678.jpg
#   inflating: data/train/0_real/000000243831.jpg
#   inflating: __MACOSX/data/train/0_real/._000000243831.jpg
#   inflating: data/train/0_real/000000245298.jpg
#   inflating: __MACOSX/data/train/0_real/._000000245298.jpg
#   inflating: data/train/0_real/000000111117.jpg
#   inflating: __MACOSX/data/train/0_real/._000000111117.jpg
#   inflating: data/train/0_real/000000330175.jpg
#   inflating: __MACOSX/data/train/0_real/._000000330175.jpg
#   inflating: data/train/0_real/000000427120.jpg
#   inflating: __MACOSX/data/train/0_real/._000000427120.jpg
#   inflating: data/train/0_real/000000461175.jpg
#   inflating: __MACOSX/data/train/0_real/._000000461175.jpg
#   inflating: data/train/0_real/000000185004.jpg
#   inflating: __MACOSX/data/train/0_real/._000000185004.jpg
#   inflating: data/train/0_real/000000226065.jpg
#   inflating: __MACOSX/data/train/0_real/._000000226065.jpg
#   inflating: data/train/0_real/000000229356.jpg
#   inflating: __MACOSX/data/train/0_real/._000000229356.jpg
#   inflating: data/train/0_real/000000113700.jpg
#   inflating: __MACOSX/data/train/0_real/._000000113700.jpg
#   inflating: data/train/0_real/000000266441.jpg
#   inflating: __MACOSX/data/train/0_real/._000000266441.jpg
#   inflating: data/train/0_real/000000279561.jpg
#   inflating: __MACOSX/data/train/0_real/._000000279561.jpg
#   inflating: data/train/0_real/000000389692.jpg
#   inflating: __MACOSX/data/train/0_real/._000000389692.jpg
#   inflating: data/train/0_real/000000473571.jpg
#   inflating: __MACOSX/data/train/0_real/._000000473571.jpg
#   inflating: data/train/0_real/000000172665.jpg
#   inflating: __MACOSX/data/train/0_real/._000000172665.jpg
#   inflating: data/train/0_real/000000211346.jpg
#   inflating: __MACOSX/data/train/0_real/._000000211346.jpg
#   inflating: data/train/0_real/000000353607.jpg
#   inflating: __MACOSX/data/train/0_real/._000000353607.jpg
#   inflating: data/train/0_real/000000027658.jpg
#   inflating: __MACOSX/data/train/0_real/._000000027658.jpg
#   inflating: data/train/0_real/000000549404.jpg
#   inflating: __MACOSX/data/train/0_real/._000000549404.jpg
#   inflating: data/train/0_real/000000400010.jpg
#   inflating: __MACOSX/data/train/0_real/._000000400010.jpg
#   inflating: data/train/0_real/000000573954.jpg
#   inflating: __MACOSX/data/train/0_real/._000000573954.jpg
#   inflating: data/train/0_real/000000099808.jpg
#   inflating: __MACOSX/data/train/0_real/._000000099808.jpg
#   inflating: data/train/0_real/000000073209.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073209.jpg
#   inflating: data/train/0_real/000000245717.jpg
#   inflating: __MACOSX/data/train/0_real/._000000245717.jpg
#   inflating: data/train/0_real/000000440352.jpg
#   inflating: __MACOSX/data/train/0_real/._000000440352.jpg
#   inflating: data/train/0_real/000000289309.jpg
#   inflating: __MACOSX/data/train/0_real/._000000289309.jpg
#   inflating: data/train/0_real/000000476838.jpg
#   inflating: __MACOSX/data/train/0_real/._000000476838.jpg
#   inflating: data/train/0_real/000000512400.jpg
#   inflating: __MACOSX/data/train/0_real/._000000512400.jpg
#   inflating: data/train/0_real/000000385241.jpg
#   inflating: __MACOSX/data/train/0_real/._000000385241.jpg
#   inflating: data/train/0_real/000000183844.jpg
#   inflating: __MACOSX/data/train/0_real/._000000183844.jpg
#   inflating: data/train/0_real/000000350468.jpg
#   inflating: __MACOSX/data/train/0_real/._000000350468.jpg
#   inflating: data/train/0_real/000000321291.jpg
#   inflating: __MACOSX/data/train/0_real/._000000321291.jpg
#   inflating: data/train/0_real/000000407019.jpg
#   inflating: __MACOSX/data/train/0_real/._000000407019.jpg
#   inflating: data/train/0_real/000000443883.jpg
#   inflating: __MACOSX/data/train/0_real/._000000443883.jpg
#   inflating: data/train/0_real/000000191298.jpg
#   inflating: __MACOSX/data/train/0_real/._000000191298.jpg
#   inflating: data/train/0_real/000000114286.jpg
#   inflating: __MACOSX/data/train/0_real/._000000114286.jpg
#   inflating: data/train/0_real/000000528788.jpg
#   inflating: __MACOSX/data/train/0_real/._000000528788.jpg
#   inflating: data/train/0_real/000000077709.jpg
#   inflating: __MACOSX/data/train/0_real/._000000077709.jpg
#   inflating: data/train/0_real/000000399668.jpg
#   inflating: __MACOSX/data/train/0_real/._000000399668.jpg
#   inflating: data/train/0_real/000000132527.jpg
#   inflating: __MACOSX/data/train/0_real/._000000132527.jpg
#   inflating: data/train/0_real/000000104081.jpg
#   inflating: __MACOSX/data/train/0_real/._000000104081.jpg
#   inflating: data/train/0_real/000000284639.jpg
#   inflating: __MACOSX/data/train/0_real/._000000284639.jpg
#   inflating: data/train/0_real/000000566395.jpg
#   inflating: __MACOSX/data/train/0_real/._000000566395.jpg
#   inflating: data/train/0_real/000000208165.jpg
#   inflating: __MACOSX/data/train/0_real/._000000208165.jpg
#   inflating: data/train/0_real/000000095940.jpg
#   inflating: __MACOSX/data/train/0_real/._000000095940.jpg
#   inflating: data/train/0_real/000000550627.jpg
#   inflating: __MACOSX/data/train/0_real/._000000550627.jpg
#   inflating: data/train/0_real/000000225949.jpg
#   inflating: __MACOSX/data/train/0_real/._000000225949.jpg
#   inflating: data/train/0_real/000000395046.jpg
#   inflating: __MACOSX/data/train/0_real/._000000395046.jpg
#   inflating: data/train/0_real/000000121229.jpg
#   inflating: __MACOSX/data/train/0_real/._000000121229.jpg
#   inflating: data/train/0_real/000000316429.jpg
#   inflating: __MACOSX/data/train/0_real/._000000316429.jpg
#   inflating: data/train/0_real/000000130324.jpg
#   inflating: __MACOSX/data/train/0_real/._000000130324.jpg
#   inflating: data/train/0_real/000000410571.jpg
#   inflating: __MACOSX/data/train/0_real/._000000410571.jpg
#   inflating: data/train/0_real/000000358020.jpg
#   inflating: __MACOSX/data/train/0_real/._000000358020.jpg
#   inflating: data/train/0_real/000000100581.jpg
#   inflating: __MACOSX/data/train/0_real/._000000100581.jpg
#   inflating: data/train/0_real/000000204039.jpg
#   inflating: __MACOSX/data/train/0_real/._000000204039.jpg
#   inflating: data/train/0_real/000000484304.jpg
#   inflating: __MACOSX/data/train/0_real/._000000484304.jpg
#   inflating: data/train/0_real/000000359458.jpg
#   inflating: __MACOSX/data/train/0_real/._000000359458.jpg
#   inflating: data/train/0_real/000000070714.jpg
#   inflating: __MACOSX/data/train/0_real/._000000070714.jpg
#   inflating: data/train/0_real/000000164013.jpg
#   inflating: __MACOSX/data/train/0_real/._000000164013.jpg
#   inflating: data/train/0_real/000000546723.jpg
#   inflating: __MACOSX/data/train/0_real/._000000546723.jpg
#   inflating: data/train/0_real/000000518139.jpg
#   inflating: __MACOSX/data/train/0_real/._000000518139.jpg
#   inflating: data/train/0_real/000000162462.jpg
#   inflating: __MACOSX/data/train/0_real/._000000162462.jpg
#   inflating: data/train/0_real/000000334850.jpg
#   inflating: __MACOSX/data/train/0_real/._000000334850.jpg
#   inflating: data/train/0_real/000000549410.jpg
#   inflating: __MACOSX/data/train/0_real/._000000549410.jpg
#   inflating: data/train/0_real/000000065457.jpg
#   inflating: __MACOSX/data/train/0_real/._000000065457.jpg
#   inflating: data/train/0_real/000000485032.jpg
#   inflating: __MACOSX/data/train/0_real/._000000485032.jpg
#   inflating: data/train/0_real/000000299640.jpg
#   inflating: __MACOSX/data/train/0_real/._000000299640.jpg
#   inflating: data/train/0_real/000000368875.jpg
#   inflating: __MACOSX/data/train/0_real/._000000368875.jpg
#   inflating: data/train/0_real/000000073235.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073235.jpg
#   inflating: data/train/0_real/000000382274.jpg
#   inflating: __MACOSX/data/train/0_real/._000000382274.jpg
#   inflating: data/train/0_real/000000177721.jpg
#   inflating: __MACOSX/data/train/0_real/._000000177721.jpg
#   inflating: data/train/0_real/000000286760.jpg
#   inflating: __MACOSX/data/train/0_real/._000000286760.jpg
#   inflating: data/train/0_real/000000149817.jpg
#   inflating: __MACOSX/data/train/0_real/._000000149817.jpg
#   inflating: data/train/0_real/000000021215.jpg
#   inflating: __MACOSX/data/train/0_real/._000000021215.jpg
#   inflating: data/train/0_real/000000256031.jpg
#   inflating: __MACOSX/data/train/0_real/._000000256031.jpg
#   inflating: data/train/0_real/000000508302.jpg
#   inflating: __MACOSX/data/train/0_real/._000000508302.jpg
#   inflating: data/train/0_real/000000413736.jpg
#   inflating: __MACOSX/data/train/0_real/._000000413736.jpg
#   inflating: data/train/0_real/000000037477.jpg
#   inflating: __MACOSX/data/train/0_real/._000000037477.jpg
#   inflating: data/train/0_real/000000029891.jpg
#   inflating: __MACOSX/data/train/0_real/._000000029891.jpg
#   inflating: data/train/0_real/000000038022.jpg
#   inflating: __MACOSX/data/train/0_real/._000000038022.jpg
#   inflating: data/train/0_real/000000445216.jpg
#   inflating: __MACOSX/data/train/0_real/._000000445216.jpg
#   inflating: data/train/0_real/000000210702.jpg
#   inflating: __MACOSX/data/train/0_real/._000000210702.jpg
#   inflating: data/train/0_real/000000157397.jpg
#   inflating: __MACOSX/data/train/0_real/._000000157397.jpg
#   inflating: data/train/0_real/000000553306.jpg
#   inflating: __MACOSX/data/train/0_real/._000000553306.jpg
#   inflating: data/train/0_real/000000075122.jpg
#   inflating: __MACOSX/data/train/0_real/._000000075122.jpg
#   inflating: data/train/0_real/000000347128.jpg
#   inflating: __MACOSX/data/train/0_real/._000000347128.jpg
#   inflating: data/train/0_real/000000545564.jpg
#   inflating: __MACOSX/data/train/0_real/._000000545564.jpg
#   inflating: data/train/0_real/000000338924.jpg
#   inflating: __MACOSX/data/train/0_real/._000000338924.jpg
#   inflating: data/train/0_real/000000359302.jpg
#   inflating: __MACOSX/data/train/0_real/._000000359302.jpg
#   inflating: data/train/0_real/000000109599.jpg
#   inflating: __MACOSX/data/train/0_real/._000000109599.jpg
#   inflating: data/train/0_real/000000450169.jpg
#   inflating: __MACOSX/data/train/0_real/._000000450169.jpg
#   inflating: data/train/0_real/000000392715.jpg
#   inflating: __MACOSX/data/train/0_real/._000000392715.jpg
#   inflating: data/train/0_real/000000565878.jpg
#   inflating: __MACOSX/data/train/0_real/._000000565878.jpg
#   inflating: data/train/0_real/000000316415.jpg
#   inflating: __MACOSX/data/train/0_real/._000000316415.jpg
#   inflating: data/train/0_real/000000494895.jpg
#   inflating: __MACOSX/data/train/0_real/._000000494895.jpg
#   inflating: data/train/0_real/000000354626.jpg
#   inflating: __MACOSX/data/train/0_real/._000000354626.jpg
#   inflating: data/train/0_real/000000527493.jpg
#   inflating: __MACOSX/data/train/0_real/._000000527493.jpg
#   inflating: data/train/0_real/000000026208.jpg
#   inflating: __MACOSX/data/train/0_real/._000000026208.jpg
#   inflating: data/train/0_real/000000078412.jpg
#   inflating: __MACOSX/data/train/0_real/._000000078412.jpg
#   inflating: data/train/0_real/000000389453.jpg
#   inflating: __MACOSX/data/train/0_real/._000000389453.jpg
#   inflating: data/train/0_real/000000557174.jpg
#   inflating: __MACOSX/data/train/0_real/._000000557174.jpg
#   inflating: data/train/0_real/000000077721.jpg
#   inflating: __MACOSX/data/train/0_real/._000000077721.jpg
#   inflating: data/train/0_real/000000511121.jpg
#   inflating: __MACOSX/data/train/0_real/._000000511121.jpg
#   inflating: data/train/0_real/000000266680.jpg
#   inflating: __MACOSX/data/train/0_real/._000000266680.jpg
#   inflating: data/train/0_real/000000067532.jpg
#   inflating: __MACOSX/data/train/0_real/._000000067532.jpg
#   inflating: data/train/0_real/000000143490.jpg
#   inflating: __MACOSX/data/train/0_real/._000000143490.jpg
#   inflating: data/train/0_real/000000548732.jpg
#   inflating: __MACOSX/data/train/0_real/._000000548732.jpg
#   inflating: data/train/0_real/000000304777.jpg
#   inflating: __MACOSX/data/train/0_real/._000000304777.jpg
#   inflating: data/train/0_real/000000092975.jpg
#   inflating: __MACOSX/data/train/0_real/._000000092975.jpg
#   inflating: data/train/0_real/000000389335.jpg
#   inflating: __MACOSX/data/train/0_real/._000000389335.jpg
#   inflating: data/train/0_real/000000303018.jpg
#   inflating: __MACOSX/data/train/0_real/._000000303018.jpg
#   inflating: data/train/0_real/000000188087.jpg
#   inflating: __MACOSX/data/train/0_real/._000000188087.jpg
#   inflating: data/train/0_real/000000487631.jpg
#   inflating: __MACOSX/data/train/0_real/._000000487631.jpg
#   inflating: data/train/0_real/000000344353.jpg
#   inflating: __MACOSX/data/train/0_real/._000000344353.jpg
#   inflating: data/train/0_real/000000387318.jpg
#   inflating: __MACOSX/data/train/0_real/._000000387318.jpg
#   inflating: data/train/0_real/000000175122.jpg
#   inflating: __MACOSX/data/train/0_real/._000000175122.jpg
#   inflating: data/train/0_real/000000065443.jpg
#   inflating: __MACOSX/data/train/0_real/._000000065443.jpg
#   inflating: data/train/0_real/000000161157.jpg
#   inflating: __MACOSX/data/train/0_real/._000000161157.jpg
#   inflating: data/train/0_real/000000254632.jpg
#   inflating: __MACOSX/data/train/0_real/._000000254632.jpg
#   inflating: data/train/0_real/000000418677.jpg
#   inflating: __MACOSX/data/train/0_real/._000000418677.jpg
#   inflating: data/train/0_real/000000299654.jpg
#   inflating: __MACOSX/data/train/0_real/._000000299654.jpg
#   inflating: data/train/0_real/000000346544.jpg
#   inflating: __MACOSX/data/train/0_real/._000000346544.jpg
#   inflating: data/train/0_real/000000022708.jpg
#   inflating: __MACOSX/data/train/0_real/._000000022708.jpg
#   inflating: data/train/0_real/000000214216.jpg
#   inflating: __MACOSX/data/train/0_real/._000000214216.jpg
# ...
#   inflating: data/train/0_real/000000497757.jpg
#   inflating: __MACOSX/data/train/0_real/._000000497757.jpg
#   inflating: data/train/0_real/000000031367.jpg
#   inflating: __MACOSX/data/train/0_real/._000000031367.jpg
#   inflating: data/train/0_real/000000209654.jpg
#   inflating: __MACOSX/data/train/0_real/._000000209654.jpg
#   inflating: data/train/0_real/000000363499.jpg
#   inflating: __MACOSX/data/train/0_real/._000000363499.jpg
#   inflating: data/train/0_real/000000051493.jpg
#   inflating: __MACOSX/data/train/0_real/._000000051493.jpg
#   inflating: data/train/0_real/000000249264.jpg
#   inflating: __MACOSX/data/train/0_real/._000000249264.jpg
#   inflating: data/train/0_real/000000362793.jpg
#   inflating: __MACOSX/data/train/0_real/._000000362793.jpg
#   inflating: data/train/0_real/000000547760.jpg
#   inflating: __MACOSX/data/train/0_real/._000000547760.jpg
#   inflating: data/train/0_real/000000389054.jpg
#   inflating: __MACOSX/data/train/0_real/._000000389054.jpg
#   inflating: data/train/0_real/000000173632.jpg
#   inflating: __MACOSX/data/train/0_real/._000000173632.jpg
#   inflating: data/train/0_real/000000557573.jpg
#   inflating: __MACOSX/data/train/0_real/._000000557573.jpg
#   inflating: data/train/0_real/000000294011.jpg
#   inflating: __MACOSX/data/train/0_real/._000000294011.jpg
#   inflating: data/train/0_real/000000038431.jpg
#   inflating: __MACOSX/data/train/0_real/._000000038431.jpg
#   inflating: data/train/0_real/000000179479.jpg
#   inflating: __MACOSX/data/train/0_real/._000000179479.jpg
#   inflating: data/train/0_real/000000436833.jpg
#   inflating: __MACOSX/data/train/0_real/._000000436833.jpg
#   inflating: data/train/0_real/000000429913.jpg
#   inflating: __MACOSX/data/train/0_real/._000000429913.jpg
#   inflating: data/train/0_real/000000111909.jpg
#   inflating: __MACOSX/data/train/0_real/._000000111909.jpg
#   inflating: data/train/0_real/000000099599.jpg
#   inflating: __MACOSX/data/train/0_real/._000000099599.jpg
#   inflating: data/train/0_real/000000515998.jpg
#   inflating: __MACOSX/data/train/0_real/._000000515998.jpg
#   inflating: data/train/0_real/000000147597.jpg
#   inflating: __MACOSX/data/train/0_real/._000000147597.jpg
#   inflating: data/train/0_real/000000063353.jpg
#   inflating: __MACOSX/data/train/0_real/._000000063353.jpg
#   inflating: data/train/0_real/000000121612.jpg
#   inflating: __MACOSX/data/train/0_real/._000000121612.jpg
#   inflating: data/train/0_real/000000252122.jpg
#   inflating: __MACOSX/data/train/0_real/._000000252122.jpg
#   inflating: data/train/0_real/000000289040.jpg
#   inflating: __MACOSX/data/train/0_real/._000000289040.jpg
#   inflating: data/train/0_real/000000073626.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073626.jpg
#   inflating: data/train/0_real/000000385108.jpg
#   inflating: __MACOSX/data/train/0_real/._000000385108.jpg
#   inflating: data/train/0_real/000000109820.jpg
#   inflating: __MACOSX/data/train/0_real/._000000109820.jpg
#   inflating: data/train/0_real/000000350721.jpg
#   inflating: __MACOSX/data/train/0_real/._000000350721.jpg
#   inflating: data/train/0_real/000000340532.jpg
#   inflating: __MACOSX/data/train/0_real/._000000340532.jpg
#   inflating: data/train/0_real/000000150955.jpg
#   inflating: __MACOSX/data/train/0_real/._000000150955.jpg
#   inflating: data/train/0_real/000000514338.jpg
#   inflating: __MACOSX/data/train/0_real/._000000514338.jpg
#   inflating: data/train/0_real/000000337962.jpg
#   inflating: __MACOSX/data/train/0_real/._000000337962.jpg
#   inflating: data/train/0_real/000000216006.jpg
#   inflating: __MACOSX/data/train/0_real/._000000216006.jpg
#   inflating: data/train/0_real/000000529907.jpg
#   inflating: __MACOSX/data/train/0_real/._000000529907.jpg
#   inflating: data/train/0_real/000000355881.jpg
#   inflating: __MACOSX/data/train/0_real/._000000355881.jpg
#   inflating: data/train/0_real/000000260190.jpg
#   inflating: __MACOSX/data/train/0_real/._000000260190.jpg
#   inflating: data/train/0_real/000000364484.jpg
#   inflating: __MACOSX/data/train/0_real/._000000364484.jpg
#   inflating: data/train/0_real/000000531190.jpg
#   inflating: __MACOSX/data/train/0_real/._000000531190.jpg
#   inflating: data/train/0_real/000000164428.jpg
#   inflating: __MACOSX/data/train/0_real/._000000164428.jpg
#   inflating: data/train/0_real/000000282115.jpg
#   inflating: __MACOSX/data/train/0_real/._000000282115.jpg
#   inflating: data/train/0_real/000000443512.jpg
#   inflating: __MACOSX/data/train/0_real/._000000443512.jpg
#   inflating: data/train/0_real/000000113893.jpg
#   inflating: __MACOSX/data/train/0_real/._000000113893.jpg
#   inflating: data/train/0_real/000000078798.jpg
#   inflating: __MACOSX/data/train/0_real/._000000078798.jpg
#   inflating: data/train/0_real/000000271076.jpg
#   inflating: __MACOSX/data/train/0_real/._000000271076.jpg
#   inflating: data/train/0_real/000000305085.jpg
#   inflating: __MACOSX/data/train/0_real/._000000305085.jpg
#   inflating: data/train/0_real/000000046676.jpg
#   inflating: __MACOSX/data/train/0_real/._000000046676.jpg
#   inflating: data/train/0_real/000000490979.jpg
#   inflating: __MACOSX/data/train/0_real/._000000490979.jpg
#   inflating: data/train/0_real/000000396821.jpg
#   inflating: __MACOSX/data/train/0_real/._000000396821.jpg
#   inflating: data/train/0_real/000000382854.jpg
#   inflating: __MACOSX/data/train/0_real/._000000382854.jpg
#   inflating: data/train/0_real/000000148129.jpg
#   inflating: __MACOSX/data/train/0_real/._000000148129.jpg
#   inflating: data/train/0_real/000000460446.jpg
#   inflating: __MACOSX/data/train/0_real/._000000460446.jpg
#   inflating: data/train/0_real/000000395496.jpg
#   inflating: __MACOSX/data/train/0_real/._000000395496.jpg
#   inflating: data/train/0_real/000000159742.jpg
#   inflating: __MACOSX/data/train/0_real/._000000159742.jpg
#   inflating: data/train/0_real/000000167874.jpg
#   inflating: __MACOSX/data/train/0_real/._000000167874.jpg
#   inflating: data/train/0_real/000000045419.jpg
#   inflating: __MACOSX/data/train/0_real/._000000045419.jpg
#   inflating: data/train/0_real/000000086452.jpg
#   inflating: __MACOSX/data/train/0_real/._000000086452.jpg
#   inflating: data/train/0_real/000000235152.jpg
#   inflating: __MACOSX/data/train/0_real/._000000235152.jpg
#   inflating: data/train/0_real/000000149551.jpg
#   inflating: __MACOSX/data/train/0_real/._000000149551.jpg
#   inflating: data/train/0_real/000000180989.jpg
#   inflating: __MACOSX/data/train/0_real/._000000180989.jpg
#   inflating: data/train/0_real/000000499785.jpg
#   inflating: __MACOSX/data/train/0_real/._000000499785.jpg
#   inflating: data/train/0_real/000000248191.jpg
#   inflating: __MACOSX/data/train/0_real/._000000248191.jpg
#   inflating: data/train/0_real/000000050772.jpg
#   inflating: __MACOSX/data/train/0_real/._000000050772.jpg
#   inflating: data/train/0_real/000000303392.jpg
#   inflating: __MACOSX/data/train/0_real/._000000303392.jpg
#   inflating: data/train/0_real/000000071964.jpg
#   inflating: __MACOSX/data/train/0_real/._000000071964.jpg
#   inflating: data/train/0_real/000000258396.jpg
#   inflating: __MACOSX/data/train/0_real/._000000258396.jpg
#   inflating: data/train/0_real/000000020281.jpg
#   inflating: __MACOSX/data/train/0_real/._000000020281.jpg
#   inflating: data/train/0_real/000000577884.jpg
#   inflating: __MACOSX/data/train/0_real/._000000577884.jpg
#   inflating: data/train/0_real/000000488844.jpg
#   inflating: __MACOSX/data/train/0_real/._000000488844.jpg
#   inflating: data/train/0_real/000000536166.jpg
#   inflating: __MACOSX/data/train/0_real/._000000536166.jpg
#   inflating: data/train/0_real/000000486869.jpg
#   inflating: __MACOSX/data/train/0_real/._000000486869.jpg
#   inflating: data/train/0_real/000000380931.jpg
#   inflating: __MACOSX/data/train/0_real/._000000380931.jpg
#   inflating: data/train/0_real/000000071970.jpg
#   inflating: __MACOSX/data/train/0_real/._000000071970.jpg
#   inflating: data/train/0_real/000000281385.jpg
#   inflating: __MACOSX/data/train/0_real/._000000281385.jpg
#   inflating: data/train/0_real/000000147568.jpg
#   inflating: __MACOSX/data/train/0_real/._000000147568.jpg
#   inflating: data/train/0_real/000000013893.jpg
#   inflating: __MACOSX/data/train/0_real/._000000013893.jpg
#   inflating: data/train/0_real/000000265771.jpg
#   inflating: __MACOSX/data/train/0_real/._000000265771.jpg
#   inflating: data/train/0_real/000000178798.jpg
#   inflating: __MACOSX/data/train/0_real/._000000178798.jpg
#   inflating: data/train/0_real/000000296821.jpg
#   inflating: __MACOSX/data/train/0_real/._000000296821.jpg
#   inflating: data/train/0_real/000000385849.jpg
#   inflating: __MACOSX/data/train/0_real/._000000385849.jpg
#   inflating: data/train/0_real/000000073801.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073801.jpg
#   inflating: data/train/0_real/000000252863.jpg
#   inflating: __MACOSX/data/train/0_real/._000000252863.jpg
#   inflating: data/train/0_real/000000466745.jpg
#   inflating: __MACOSX/data/train/0_real/._000000466745.jpg
#   inflating: data/train/0_real/000000552392.jpg
#   inflating: __MACOSX/data/train/0_real/._000000552392.jpg
#   inflating: data/train/0_real/000000377361.jpg
#   inflating: __MACOSX/data/train/0_real/._000000377361.jpg
#   inflating: data/train/0_real/000000429052.jpg
#   inflating: __MACOSX/data/train/0_real/._000000429052.jpg
#   inflating: data/train/0_real/000000150772.jpg
#   inflating: __MACOSX/data/train/0_real/._000000150772.jpg
#   inflating: data/train/0_real/000000119414.jpg
#   inflating: __MACOSX/data/train/0_real/._000000119414.jpg
#   inflating: data/train/0_real/000000213181.jpg
#   inflating: __MACOSX/data/train/0_real/._000000213181.jpg
#   inflating: data/train/0_real/000000227224.jpg
#   inflating: __MACOSX/data/train/0_real/._000000227224.jpg
#   inflating: data/train/0_real/000000453926.jpg
#   inflating: __MACOSX/data/train/0_real/._000000453926.jpg
#   inflating: data/train/0_real/000000370426.jpg
#   inflating: __MACOSX/data/train/0_real/._000000370426.jpg
#   inflating: data/train/0_real/000000407387.jpg
#   inflating: __MACOSX/data/train/0_real/._000000407387.jpg
#   inflating: data/train/0_real/000000158306.jpg
#   inflating: __MACOSX/data/train/0_real/._000000158306.jpg
#   inflating: data/train/0_real/000000243946.jpg
#   inflating: __MACOSX/data/train/0_real/._000000243946.jpg
#   inflating: data/train/0_real/000000252693.jpg
#   inflating: __MACOSX/data/train/0_real/._000000252693.jpg
#   inflating: data/train/0_real/000000088325.jpg
#   inflating: __MACOSX/data/train/0_real/._000000088325.jpg
#   inflating: data/train/0_real/000000294978.jpg
#   inflating: __MACOSX/data/train/0_real/._000000294978.jpg
#   inflating: data/train/0_real/000000403687.jpg
#   inflating: __MACOSX/data/train/0_real/._000000403687.jpg
#   inflating: data/train/0_real/000000007616.jpg
#   inflating: __MACOSX/data/train/0_real/._000000007616.jpg
#   inflating: data/train/0_real/000000241837.jpg
#   inflating: __MACOSX/data/train/0_real/._000000241837.jpg
#   inflating: data/train/0_real/000000239754.jpg
#   inflating: __MACOSX/data/train/0_real/._000000239754.jpg
#   inflating: data/train/0_real/000000362744.jpg
#   inflating: __MACOSX/data/train/0_real/._000000362744.jpg
#   inflating: data/train/0_real/000000220205.jpg
#   inflating: __MACOSX/data/train/0_real/._000000220205.jpg
#   inflating: data/train/0_real/000000048101.jpg
#   inflating: __MACOSX/data/train/0_real/._000000048101.jpg
#   inflating: data/train/0_real/000000208589.jpg
#   inflating: __MACOSX/data/train/0_real/._000000208589.jpg
#   inflating: data/train/0_real/000000144049.jpg
#   inflating: __MACOSX/data/train/0_real/._000000144049.jpg
#   inflating: data/train/0_real/000000193077.jpg
#   inflating: __MACOSX/data/train/0_real/._000000193077.jpg
#   inflating: data/train/0_real/000000097563.jpg
#   inflating: __MACOSX/data/train/0_real/._000000097563.jpg
#   inflating: data/train/0_real/000000176945.jpg
#   inflating: __MACOSX/data/train/0_real/._000000176945.jpg
#   inflating: data/train/0_real/000000111706.jpg
#   inflating: __MACOSX/data/train/0_real/._000000111706.jpg
#   inflating: data/train/0_real/000000477106.jpg
#   inflating: __MACOSX/data/train/0_real/._000000477106.jpg
#   inflating: data/train/0_real/000000146886.jpg
#   inflating: __MACOSX/data/train/0_real/._000000146886.jpg
#   inflating: data/train/0_real/000000073197.jpg
#   inflating: __MACOSX/data/train/0_real/._000000073197.jpg
#   inflating: data/train/0_real/000000495183.jpg
#   inflating: __MACOSX/data/train/0_real/._000000495183.jpg
#   inflating: data/train/0_real/000000329235.jpg
#   inflating: __MACOSX/data/train/0_real/._000000329235.jpg
#   inflating: data/train/0_real/000000195406.jpg
#   inflating: __MACOSX/data/train/0_real/._000000195406.jpg
#   inflating: data/train/0_real/000000523225.jpg
#   inflating: __MACOSX/data/train/0_real/._000000523225.jpg
#   inflating: data/train/0_real/000000296809.jpg
#   inflating: __MACOSX/data/train/0_real/._000000296809.jpg
#   inflating: data/train/0_real/000000485390.jpg
#   inflating: __MACOSX/data/train/0_real/._000000485390.jpg
#   inflating: data/train/0_real/000000192369.jpg
#   inflating: __MACOSX/data/train/0_real/._000000192369.jpg
#   inflating: data/train/0_real/000000151322.jpg
#   inflating: __MACOSX/data/train/0_real/._000000151322.jpg
#   inflating: data/train/0_real/000000089991.jpg
#   inflating: __MACOSX/data/train/0_real/._000000089991.jpg
#   inflating: data/train/0_real/000000429708.jpg
#   inflating: __MACOSX/data/train/0_real/._000000429708.jpg
#   inflating: data/train/0_real/000000361259.jpg
#   inflating: __MACOSX/data/train/0_real/._000000361259.jpg
#   inflating: data/train/0_real/000000003464.jpg
#   inflating: __MACOSX/data/train/0_real/._000000003464.jpg
#   inflating: data/train/0_real/000000406933.jpg
#   inflating: __MACOSX/data/train/0_real/._000000406933.jpg
#   inflating: data/train/0_real/000000225369.jpg
#   inflating: __MACOSX/data/train/0_real/._000000225369.jpg
#   inflating: data/train/0_real/000000008531.jpg
#   inflating: __MACOSX/data/train/0_real/._000000008531.jpg
#   inflating: data/train/0_real/000000266244.jpg
#   inflating: __MACOSX/data/train/0_real/._000000266244.jpg
#   inflating: data/train/0_real/000000324705.jpg
#   inflating: __MACOSX/data/train/0_real/._000000324705.jpg
#   inflating: data/train/0_real/000000060699.jpg
#   inflating: __MACOSX/data/train/0_real/._000000060699.jpg
#   inflating: data/train/0_real/000000029299.jpg
#   inflating: __MACOSX/data/train/0_real/._000000029299.jpg
#   inflating: data/train/0_real/000000094718.jpg
#   inflating: __MACOSX/data/train/0_real/._000000094718.jpg
#   inflating: data/train/0_real/000000567315.jpg
#   inflating: __MACOSX/data/train/0_real/._000000567315.jpg
#   inflating: data/train/0_real/000000354584.jpg
#   inflating: __MACOSX/data/train/0_real/._000000354584.jpg
#   inflating: data/train/0_real/000000221669.jpg
#   inflating: __MACOSX/data/train/0_real/._000000221669.jpg
#   inflating: data/train/0_real/000000051322.jpg
#   inflating: __MACOSX/data/train/0_real/._000000051322.jpg
#   inflating: data/train/0_real/000000191112.jpg
#   inflating: __MACOSX/data/train/0_real/._000000191112.jpg
#   inflating: data/train/0_real/000000065087.jpg
#   inflating: __MACOSX/data/train/0_real/._000000065087.jpg
#   inflating: data/train/0_real/000000461016.jpg
#   inflating: __MACOSX/data/train/0_real/._000000461016.jpg
#   inflating: data/train/0_real/000000573360.jpg
#   inflating: __MACOSX/data/train/0_real/._000000573360.jpg
#   inflating: data/train/0_real/000000157021.jpg
#   inflating: __MACOSX/data/train/0_real/._000000157021.jpg
#   inflating: data/train/0_real/000000379370.jpg
#   inflating: __MACOSX/data/train/0_real/._000000379370.jpg
#   inflating: data/train/0_real/000000421432.jpg
#   inflating: __MACOSX/data/train/0_real/._000000421432.jpg

# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from tqdm import tqdm
from timm import create_model
import shutil
from pathlib import Path
import random
from sklearn.metrics import precision_recall_fscore_support, accuracy_score
import numpy as np
import csv, json

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
def split_train_to_val(source_dir, val_ratio=0.2, seed=42):
    source_dir = Path(source_dir)
    val_dir = source_dir.parent / "val"

    random.seed(seed)

    # Define class subdirectories
    classes = ["0_real", "1_fake"]

    for class_name in classes:
        train_class_dir = source_dir / class_name
        val_class_dir = val_dir / class_name

        if not train_class_dir.exists():
            print(f"Warning: {train_class_dir} does not exist. Skipping.")
            continue

        # Create validation directory
        val_class_dir.mkdir(parents=True, exist_ok=True)

        # Get all image files
        image_extensions = {'.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.webp'}
        files = [f for f in train_class_dir.iterdir()
                if f.suffix.lower() in image_extensions and f.is_file()]

        if len(files) == 0:
            print(f"No images found in {train_class_dir}")
            continue

        # Calculate number to move
        num_to_move = max(1, int(len(files) * val_ratio))  # at least 1 image
        print(f"Moving {num_to_move}/{len(files)} images from {class_name} to validation")

        # Randomly select files
        files_to_move = random.sample(files, num_to_move)

        # Move them
        for file_path in files_to_move:
            dest_path = val_class_dir / file_path.name
            shutil.move(str(file_path), str(dest_path))
            # print(f"Moved: {file_path.name} → {dest_path}")

    print(f"\nDone! Validation set created at: {val_dir}")

# %%
split_train_to_val('data/train', val_ratio=0.25, seed=42)
# Out:
# Moving 6250/25000 images from 0_real to validation
# Moving 6250/25000 images from 1_fake to validation
#
# Done! Validation set created at: data/val

# %%
class data_loader(Dataset):
    def __init__(self, data_dir):

        real = os.path.join(data_dir, '0_real')
        fake = os.path.join(data_dir, '1_fake')

        file_names_real = os.listdir(real)
        file_names_fake = os.listdir(fake)

        self.full_filenames_real = [os.path.join(real, f) for f in file_names_real]
        self.full_filenames_fake = [os.path.join(fake, f) for f in file_names_fake]
        self.full_filenames = self.full_filenames_real + self.full_filenames_fake

        self.labels_real = [0 for _ in file_names_real]
        self.labels_fake = [1 for _ in file_names_fake]
        self.labels = self.labels_real + self.labels_fake

        self.transform_original = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)
        ])

        self.transform_aug = transforms.Compose([
            transforms.RandomResizedCrop(224, scale=(0.6, 1.0)),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomRotation(30),
            transforms.RandAugment(num_ops=2, magnitude=9),
            transforms.ColorJitter(0.4, 0.4, 0.4, 0.1),
            transforms.ToTensor(),
            transforms.RandomErasing(p=0.25, scale=(0.02, 0.15), ratio=(0.3, 3.3), value='random'),
            transforms.Normalize(mean=[0.5]*3, std=[0.5]*3)
        ])

    def __len__(self):
        return len(self.full_filenames)

    def __getitem__(self, idx):
        image = Image.open(self.full_filenames[idx]).convert("RGB")
        image_aug = self.transform_aug(image)
        image_original = self.transform_original(image)
        label = self.labels[idx]
        return image_original, image_aug, label

# %%
# @title
# ===============================
# Neural NetWork
# ===============================
class CNN(nn.Module):
    def __init__(self, pretrained=True, freeze_backbone=True, dropout=0.3):
        super(CNN, self).__init__()

        # === ViT-B ===
        self.vit = create_model('vit_base_patch16_224', pretrained=pretrained, num_classes=0)  # 768-dim
        # === Swin-B ===
        self.swin = create_model('swin_base_patch4_window7_224', pretrained=pretrained, num_classes=0)  # 1024-dim

        # Freeze backbones (recommended for AIGC detection with limited data)
        if freeze_backbone:
            for param in self.vit.parameters():
                param.requires_grad = False
            for param in self.swin.parameters():
                param.requires_grad = False


        # Fusion MLP: 768 + 1024
        self.fusion = nn.Sequential(
            # 768 + 1024 → 512
            nn.Linear(768 + 1024, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            # 512 → 128
            nn.Linear(512, 128),
            nn.BatchNorm1d(128),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            # 128 → 2
            nn.Linear(128, 2)  # 2 classes: real vs AIGC
        )

    def forward(self, x):
        # Extract features with both ViT and Swin
        vit_feat = self.vit(x)
        swin_feat = self.swin(x)

        # For Swin, forward_features returns [B, H*W, C] → global avg pool if needed
        if len(swin_feat.shape) == 3:
            swin_feat = swin_feat.mean(1)  # [B, 1024]

        # Concatenate feature vectors
        combined = torch.cat([vit_feat, swin_feat], dim=1)  # [B, 1792]

        # Final classification
        out = self.fusion(combined)
        return out

# %%
# ===============================
# Train-Validate
# ===============================
def main():
    data_root = "data"
    batch_size = 32 # Smaller batch = better generalization with dual-view
    epochs_list = [5, 10, 15]
    lr = 3e-5 # Lower LR works much better when unfreezing layers

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Training on {device}")

    # For each epochs, reset all settings
    for epochs in epochs_list:
        # ===============================
        # Metrics Logging Setup
        # ===============================
        metrics_log = {
            "train_loss": [], "train_acc": [], "train_prec": [], "train_rec": [], "train_f1": [],
            "val_acc": [], "val_prec": [], "val_rec": [], "val_f1": []
        }

        os.makedirs("logs", exist_ok=True)
        csv_path  = f"logs/vit_swin_training_metrics_{epochs}e.csv"
        json_path = f"logs/vit_swin_training_metrics_{epochs}e.json"
        # ===============================
        # Dataset & Dataloader
        # ===============================
        train_dataset = data_loader(os.path.join(data_root, "train"))
        val_dataset = data_loader(os.path.join(data_root, "val"))

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                                num_workers=4, pin_memory=True, drop_last=True)
        val_loader = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False,
                                num_workers=4, pin_memory=True)

        # ===============================
        # Model + Optimizer + Loss
        # ===============================
        model = CNN().to(device)

        # Unfreeze last few blocks
        for p in model.vit.blocks[-3:].parameters():
            p.requires_grad = True
        for p in model.swin.layers[-2:].parameters():
            p.requires_grad = True

        optimizer = torch.optim.AdamW(
            filter(lambda p: p.requires_grad, model.parameters()),
            lr=lr,
            weight_decay=1e-4
        )
        criterion = nn.CrossEntropyLoss(label_smoothing=0.1)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs, eta_min=1e-6)
        best_val_f1 = 0.0
        best_val_acc = 0.0

        for epoch in range(epochs):
            # ------------------- Training -------------------
            model.train()
            total_loss = 0.0
            train_all_preds = []
            train_all_labels = []

            pbar = tqdm(train_loader, desc=f"Epoch {epoch+1:02d}/{epochs} [Train]")

            for img_clean, img_aug, labels in pbar:
                img_clean = img_clean.to(device, non_blocking=True)
                img_aug = img_aug.to(device, non_blocking=True)
                labels = labels.to(device, non_blocking=True)

                optimizer.zero_grad()
                logits_clean = model(img_clean)
                logits_aug   = model(img_aug)

                # Proper dual-view ensembling
                logits = (logits_clean + logits_aug) / 2.0
                loss = criterion(logits, labels)
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
                preds = logits.argmax(dim=1)

                train_all_preds.extend(preds.cpu().numpy())
                train_all_labels.extend(labels.cpu().numpy())

                pbar.set_postfix({"Loss": f"{total_loss/(epoch+1):.4f}"})

            # Training metrics
            train_acc  = accuracy_score(train_all_labels, train_all_preds)
            train_prec, train_rec, train_f1, _ = precision_recall_fscore_support(
                train_all_labels, train_all_preds, average='macro', zero_division=0
            )
            avg_train_loss = total_loss / len(train_loader)

            # ------------------- Validation -------------------
            model.eval()
            val_all_preds = []
            val_all_labels = []

            with torch.no_grad():
                for img_clean, _, labels in val_loader:
                    img_clean = img_clean.to(device)
                    labels = labels.to(device)
                    logits = model(img_clean)
                    preds = logits.argmax(dim=1)
                    val_all_preds.extend(preds.cpu().numpy())
                    val_all_labels.extend(labels.cpu().numpy())

            val_acc = accuracy_score(val_all_labels, val_all_preds)
            val_prec, val_rec, val_f1, _ = precision_recall_fscore_support(
                val_all_labels, val_all_preds, average='macro', zero_division=0
            )

            scheduler.step()

            # Save best model (by macro F1)
            if val_f1 > best_val_f1:
                best_val_f1 = val_f1
                best_val_acc = val_acc
                torch.save(model.state_dict(), "model_best.pth")
                print(f"New best model saved! Val F1: {val_f1:.4f} | Val Acc: {val_acc:.4f}")

            # ===============================
            # Log metrics for this epoch
            # ===============================
            metrics_log["train_loss"].append(avg_train_loss)
            metrics_log["train_acc"].append(train_acc)
            metrics_log["train_prec"].append(train_prec)
            metrics_log["train_rec"].append(train_rec)
            metrics_log["train_f1"].append(train_f1)
            metrics_log["val_acc"].append(val_acc)
            metrics_log["val_prec"].append(val_prec)
            metrics_log["val_rec"].append(val_rec)
            metrics_log["val_f1"].append(val_f1)

            # Print epoch summary
            print(f"\n=== Epoch {epoch+1:02d}/{epochs} ===")
            print(f"Train → Loss: {avg_train_loss:.4f} | Acc: {train_acc:.4f} | P: {train_prec:.4f} | R: {train_rec:.4f} | F1: {train_f1:.4f}")
            print(f"Val   → Acc: {val_acc:.4f} | P: {val_prec:.4f} | R: {val_rec:.4f} | F1: {val_f1:.4f}")
            print(f"Best Val → Acc: {best_val_acc:.4f} | F1: {best_val_f1:.4f}\n")

        # ===============================
        # Save Metrics to CSV & JSON
        # ===============================
        # CSV
        with open(csv_path, mode='w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Epoch", "Train_Loss", "Train_Acc", "Train_Prec", "Train_Rec", "Train_F1",
                            "Val_Acc", "Val_Prec", "Val_Rec", "Val_F1"])
            for i in range(epochs):
                writer.writerow([
                    i,
                    f"{metrics_log['train_loss'][i]:.4f}",
                    f"{metrics_log['train_acc'][i]:.4f}",
                    f"{metrics_log['train_prec'][i]:.4f}",
                    f"{metrics_log['train_rec'][i]:.4f}",
                    f"{metrics_log['train_f1'][i]:.4f}",
                    f"{metrics_log['val_acc'][i]:.4f}",
                    f"{metrics_log['val_prec'][i]:.4f}",
                    f"{metrics_log['val_rec'][i]:.4f}",
                    f"{metrics_log['val_f1'][i]:.4f}",
                ])

        # JSON (extra backup + easy to load later)
        log_to_save = {k: [f"{v:.6f}" if isinstance(v, float) else v for v in vals]
                    for k, vals in metrics_log.items()}
        log_to_save["best_val_accuracy"] = f"{best_val_acc:.6f}"
        log_to_save["best_val_f1"] = f"{best_val_f1:.6f}"
        log_to_save["total_epochs"] = epochs

        with open(json_path, 'w') as f:
            json.dump(log_to_save, f, indent=2)

        print(f"All metrics saved!")
        print(f"   → CSV : {csv_path}")
        print(f"   → JSON: {json_path}")
        print(f"Final Best Val Accuracy: {best_val_acc:.4f} | Best Val F1: {best_val_f1:.4f}\n{'='*60}\n")

        # Final save per epoch count
        torch.save(model.state_dict(), f"drive/MyDrive/CS4487/ViTB_Swin_{epochs}e.pth")
        print(f"Training with {epochs} epochs finished!")
        print(f"Final Best Val Accuracy: {best_val_acc:.4f} | Best Val F1: {best_val_f1:.4f}\n")

# %%
if __name__ == "__main__":
    main()
# Out:
# Training on cuda
# Epoch 01/5 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=289.6268]
# New best model saved! Val F1: 0.9962 | Val Acc: 0.9962
#
# === Epoch 01/5 ===
# Train → Loss: 0.2473 | Acc: 0.9776 | P: 0.9776 | R: 0.9776 | F1: 0.9776
# Val   → Acc: 0.9962 | P: 0.9962 | R: 0.9962 | F1: 0.9962
# Best Val → Acc: 0.9962 | F1: 0.9962
# Epoch 02/5 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=127.5158]
# New best model saved! Val F1: 0.9972 | Val Acc: 0.9972
#
# === Epoch 02/5 ===
# Train → Loss: 0.2178 | Acc: 0.9950 | P: 0.9950 | R: 0.9950 | F1: 0.9950
# Val   → Acc: 0.9972 | P: 0.9972 | R: 0.9972 | F1: 0.9972
# Best Val → Acc: 0.9972 | F1: 0.9972
# Epoch 03/5 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=82.6324]
# === Epoch 03/5 ===
# Train → Loss: 0.2117 | Acc: 0.9978 | P: 0.9978 | R: 0.9978 | F1: 0.9978
# Val   → Acc: 0.9945 | P: 0.9945 | R: 0.9945 | F1: 0.9945
# Best Val → Acc: 0.9972 | F1: 0.9972
# Epoch 04/5 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=61.4653]
# New best model saved! Val F1: 0.9987 | Val Acc: 0.9987
#
# === Epoch 04/5 ===
# Train → Loss: 0.2100 | Acc: 0.9988 | P: 0.9988 | R: 0.9988 | F1: 0.9988
# Val   → Acc: 0.9987 | P: 0.9987 | R: 0.9987 | F1: 0.9987
# Best Val → Acc: 0.9987 | F1: 0.9987
# Epoch 05/5 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=48.6449]
# === Epoch 05/5 ===
# Train → Loss: 0.2077 | Acc: 0.9998 | P: 0.9998 | R: 0.9998 | F1: 0.9998
# Val   → Acc: 0.9978 | P: 0.9978 | R: 0.9978 | F1: 0.9978
# Best Val → Acc: 0.9987 | F1: 0.9987
#
# All metrics saved!
#    → CSV : logs/vit_swin_training_metrics_5e.csv
#    → JSON: logs/vit_swin_training_metrics_5e.json
# Final Best Val Accuracy: 0.9987 | Best Val F1: 0.9987
# ============================================================
#
# Training with 5 epochs finished!
# Final Best Val Accuracy: 0.9987 | Best Val F1: 0.9987
# Epoch 01/10 [Train]: 100%|██████████| 1171/1171 [27:06<00:00,  1.39s/it, Loss=283.4294]
# New best model saved! Val F1: 0.9956 | Val Acc: 0.9956
#
# === Epoch 01/10 ===
# Train → Loss: 0.2420 | Acc: 0.9803 | P: 0.9805 | R: 0.9803 | F1: 0.9803
# Val   → Acc: 0.9956 | P: 0.9956 | R: 0.9956 | F1: 0.9956
# Best Val → Acc: 0.9956 | F1: 0.9956
# Epoch 02/10 [Train]: 100%|██████████| 1171/1171 [27:06<00:00,  1.39s/it, Loss=127.4506]
# === Epoch 02/10 ===
# Train → Loss: 0.2177 | Acc: 0.9948 | P: 0.9949 | R: 0.9948 | F1: 0.9948
# Val   → Acc: 0.9950 | P: 0.9951 | R: 0.9950 | F1: 0.9950
# Best Val → Acc: 0.9956 | F1: 0.9956
# Epoch 03/10 [Train]: 100%|██████████| 1171/1171 [27:06<00:00,  1.39s/it, Loss=83.2483]
# New best model saved! Val F1: 0.9966 | Val Acc: 0.9966
#
# === Epoch 03/10 ===
# Train → Loss: 0.2133 | Acc: 0.9967 | P: 0.9967 | R: 0.9967 | F1: 0.9967
# Val   → Acc: 0.9966 | P: 0.9966 | R: 0.9966 | F1: 0.9966
# Best Val → Acc: 0.9966 | F1: 0.9966
# Epoch 04/10 [Train]: 100%|██████████| 1171/1171 [27:06<00:00,  1.39s/it, Loss=61.6464]
# === Epoch 04/10 ===
# Train → Loss: 0.2106 | Acc: 0.9978 | P: 0.9978 | R: 0.9978 | F1: 0.9978
# Val   → Acc: 0.9964 | P: 0.9964 | R: 0.9964 | F1: 0.9964
# Best Val → Acc: 0.9966 | F1: 0.9966
# Epoch 05/10 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=48.6578]
# New best model saved! Val F1: 0.9983 | Val Acc: 0.9983
#
# === Epoch 05/10 ===
# Train → Loss: 0.2078 | Acc: 0.9987 | P: 0.9987 | R: 0.9987 | F1: 0.9987
# Val   → Acc: 0.9983 | P: 0.9983 | R: 0.9983 | F1: 0.9983
# Best Val → Acc: 0.9983 | F1: 0.9983
# Epoch 06/10 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=40.1541]
# New best model saved! Val F1: 0.9987 | Val Acc: 0.9987
#
# === Epoch 06/10 ===
# Train → Loss: 0.2057 | Acc: 0.9995 | P: 0.9995 | R: 0.9995 | F1: 0.9995
# Val   → Acc: 0.9987 | P: 0.9987 | R: 0.9987 | F1: 0.9987
# Best Val → Acc: 0.9987 | F1: 0.9987
# Epoch 07/10 [Train]: 100%|██████████| 1171/1171 [27:08<00:00,  1.39s/it, Loss=34.2108]
# New best model saved! Val F1: 0.9989 | Val Acc: 0.9989
#
# === Epoch 07/10 ===
# Train → Loss: 0.2045 | Acc: 0.9998 | P: 0.9998 | R: 0.9998 | F1: 0.9998
# Val   → Acc: 0.9989 | P: 0.9989 | R: 0.9989 | F1: 0.9989
# Best Val → Acc: 0.9989 | F1: 0.9989
# Epoch 08/10 [Train]: 100%|██████████| 1171/1171 [27:08<00:00,  1.39s/it, Loss=29.9180]
# === Epoch 08/10 ===
# Train → Loss: 0.2044 | Acc: 0.9998 | P: 0.9998 | R: 0.9998 | F1: 0.9998
# Val   → Acc: 0.9986 | P: 0.9986 | R: 0.9986 | F1: 0.9986
# Best Val → Acc: 0.9989 | F1: 0.9989
# Epoch 09/10 [Train]: 100%|██████████| 1171/1171 [27:08<00:00,  1.39s/it, Loss=26.5536]
# New best model saved! Val F1: 0.9991 | Val Acc: 0.9991
#
# === Epoch 09/10 ===
# Train → Loss: 0.2041 | Acc: 0.9998 | P: 0.9998 | R: 0.9998 | F1: 0.9998
# Val   → Acc: 0.9991 | P: 0.9991 | R: 0.9991 | F1: 0.9991
# Best Val → Acc: 0.9991 | F1: 0.9991
# Epoch 10/10 [Train]: 100%|██████████| 1171/1171 [27:09<00:00,  1.39s/it, Loss=23.8429]
# === Epoch 10/10 ===
# Train → Loss: 0.2036 | Acc: 1.0000 | P: 1.0000 | R: 1.0000 | F1: 1.0000
# Val   → Acc: 0.9990 | P: 0.9990 | R: 0.9990 | F1: 0.9990
# Best Val → Acc: 0.9991 | F1: 0.9991
#
# All metrics saved!
#    → CSV : logs/vit_swin_training_metrics_10e.csv
#    → JSON: logs/vit_swin_training_metrics_10e.json
# Final Best Val Accuracy: 0.9991 | Best Val F1: 0.9991
# ============================================================
#
# Training with 10 epochs finished!
# Final Best Val Accuracy: 0.9991 | Best Val F1: 0.9991
# Epoch 01/15 [Train]: 100%|██████████| 1171/1171 [27:08<00:00,  1.39s/it, Loss=286.2481]
# New best model saved! Val F1: 0.9951 | Val Acc: 0.9951
#
# === Epoch 01/15 ===
# Train → Loss: 0.2444 | Acc: 0.9796 | P: 0.9796 | R: 0.9796 | F1: 0.9796
# Val   → Acc: 0.9951 | P: 0.9952 | R: 0.9951 | F1: 0.9951
# Best Val → Acc: 0.9951 | F1: 0.9951
# Epoch 02/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=127.5646]
# New best model saved! Val F1: 0.9970 | Val Acc: 0.9970
#
# === Epoch 02/15 ===
# Train → Loss: 0.2179 | Acc: 0.9946 | P: 0.9946 | R: 0.9946 | F1: 0.9946
# Val   → Acc: 0.9970 | P: 0.9970 | R: 0.9970 | F1: 0.9970
# Best Val → Acc: 0.9970 | F1: 0.9970
# Epoch 03/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=83.3853]
# New best model saved! Val F1: 0.9974 | Val Acc: 0.9974
#
# === Epoch 03/15 ===
# Train → Loss: 0.2136 | Acc: 0.9972 | P: 0.9972 | R: 0.9972 | F1: 0.9972
# Val   → Acc: 0.9974 | P: 0.9975 | R: 0.9974 | F1: 0.9974
# Best Val → Acc: 0.9974 | F1: 0.9974
# Epoch 04/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=61.9816]
# === Epoch 04/15 ===
# Train → Loss: 0.2117 | Acc: 0.9978 | P: 0.9978 | R: 0.9978 | F1: 0.9978
# Val   → Acc: 0.9966 | P: 0.9966 | R: 0.9966 | F1: 0.9966
# Best Val → Acc: 0.9974 | F1: 0.9974
# Epoch 05/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=49.0821]
# === Epoch 05/15 ===
# Train → Loss: 0.2096 | Acc: 0.9986 | P: 0.9986 | R: 0.9986 | F1: 0.9986
# Val   → Acc: 0.9965 | P: 0.9965 | R: 0.9965 | F1: 0.9965
# Best Val → Acc: 0.9974 | F1: 0.9974
# Epoch 06/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=40.4661]
# New best model saved! Val F1: 0.9979 | Val Acc: 0.9979
#
# === Epoch 06/15 ===
# Train → Loss: 0.2073 | Acc: 0.9991 | P: 0.9991 | R: 0.9991 | F1: 0.9991
# Val   → Acc: 0.9979 | P: 0.9979 | R: 0.9979 | F1: 0.9979
# Best Val → Acc: 0.9979 | F1: 0.9979
# Epoch 07/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=34.4799]
# === Epoch 07/15 ===
# Train → Loss: 0.2061 | Acc: 0.9995 | P: 0.9995 | R: 0.9995 | F1: 0.9995
# Val   → Acc: 0.9978 | P: 0.9978 | R: 0.9978 | F1: 0.9978
# Best Val → Acc: 0.9979 | F1: 0.9979
# Epoch 08/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=29.9838]
# New best model saved! Val F1: 0.9987 | Val Acc: 0.9987
#
# === Epoch 08/15 ===
# Train → Loss: 0.2048 | Acc: 0.9998 | P: 0.9998 | R: 0.9998 | F1: 0.9998
# Val   → Acc: 0.9987 | P: 0.9987 | R: 0.9987 | F1: 0.9987
# Best Val → Acc: 0.9987 | F1: 0.9987
# Epoch 09/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=26.6436]
# === Epoch 09/15 ===
# Train → Loss: 0.2048 | Acc: 0.9997 | P: 0.9997 | R: 0.9997 | F1: 0.9997
# Val   → Acc: 0.9977 | P: 0.9977 | R: 0.9977 | F1: 0.9977
# Best Val → Acc: 0.9987 | F1: 0.9987
# Epoch 10/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=23.9436]
# === Epoch 10/15 ===
# Train → Loss: 0.2045 | Acc: 0.9997 | P: 0.9997 | R: 0.9997 | F1: 0.9997
# Val   → Acc: 0.9975 | P: 0.9975 | R: 0.9975 | F1: 0.9975
# Best Val → Acc: 0.9987 | F1: 0.9987
# Epoch 11/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=21.6659]
# New best model saved! Val F1: 0.9988 | Val Acc: 0.9988
#
# === Epoch 11/15 ===
# Train → Loss: 0.2035 | Acc: 0.9999 | P: 0.9999 | R: 0.9999 | F1: 0.9999
# Val   → Acc: 0.9988 | P: 0.9988 | R: 0.9988 | F1: 0.9988
# Best Val → Acc: 0.9988 | F1: 0.9988
# Epoch 12/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=19.8429]
# === Epoch 12/15 ===
# Train → Loss: 0.2033 | Acc: 0.9999 | P: 0.9999 | R: 0.9999 | F1: 0.9999
# Val   → Acc: 0.9987 | P: 0.9987 | R: 0.9987 | F1: 0.9987
# Best Val → Acc: 0.9988 | F1: 0.9988
# Epoch 13/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=18.3044]
# === Epoch 13/15 ===
# Train → Loss: 0.2032 | Acc: 0.9999 | P: 0.9999 | R: 0.9999 | F1: 0.9999
# Val   → Acc: 0.9988 | P: 0.9988 | R: 0.9988 | F1: 0.9988
# Best Val → Acc: 0.9988 | F1: 0.9988
# Epoch 14/15 [Train]: 100%|██████████| 1171/1171 [27:06<00:00,  1.39s/it, Loss=16.9810]
# New best model saved! Val F1: 0.9990 | Val Acc: 0.9990
#
# === Epoch 14/15 ===
# Train → Loss: 0.2030 | Acc: 0.9999 | P: 0.9999 | R: 0.9999 | F1: 0.9999
# Val   → Acc: 0.9990 | P: 0.9990 | R: 0.9990 | F1: 0.9990
# Best Val → Acc: 0.9990 | F1: 0.9990
# Epoch 15/15 [Train]: 100%|██████████| 1171/1171 [27:07<00:00,  1.39s/it, Loss=15.8463]
# === Epoch 15/15 ===
# Train → Loss: 0.2030 | Acc: 1.0000 | P: 1.0000 | R: 1.0000 | F1: 1.0000
# Val   → Acc: 0.9990 | P: 0.9990 | R: 0.9990 | F1: 0.9990
# Best Val → Acc: 0.9990 | F1: 0.9990
#
# All metrics saved!
#    → CSV : logs/vit_swin_training_metrics_15e.csv
#    → JSON: logs/vit_swin_training_metrics_15e.json
# Final Best Val Accuracy: 0.9990 | Best Val F1: 0.9990
# ============================================================
#
# Training with 15 epochs finished!
# Final Best Val Accuracy: 0.9990 | Best Val F1: 0.9990

# %%
# !cp -r logs/ drive/MyDrive/CS4487/

# %%
# !cp model_best.pth drive/MyDrive/CS4487/ViTBSwinBest.pth
